# %% [markdown]
# # Webアプリに入る前に知っておくべきデータに関する前提知識

# %% [markdown]
# ### 目標：APIを理解して使いこなし、そのデータを扱えるようになる事
#
# 目次
# https://docs.google.com/document/d/1crmJ0DjAl77ab9aK8K9DshfQu25fS3EWXCC0m4AajZo/edit

# %% [markdown]
# ## 3全体像：楽天のAPIから情報を取得する

# %% [markdown]
# ### 3.1.おさらい：APIとは？

# %% [markdown]
# APIは、Application Programming Interfaceの略であり、プログラムやアプリケーション開発に必要な機能やデータを提供するインターフェースを指します。
#
# 例として、スマートフォンにはカメラアプリや音楽アプリ、地図アプリなどが存在します。これらのアプリケーションは、スマートフォンのOS（Operating System）が提供するAPIを用いて、カメラやGPS機能といったハードウェアやソフトウェアにアクセスしています。
#
# APIはアプリケーションが他のアプリケーションやシステムと連携する手段であり、開発者が他のアプリケーションやサービスと容易に連携できるように設計されています。APIにはWeb API、データベースAPI、ソーシャルメディアAPIなど、多様な種類があります。
#
# オンラインランキングやアカウントログイン機能の開発の際、GoogleやFacebookなどのサービスが提供するAPIを利用してアカウント情報を取得することができます。
#
# APIは現代のソフトウェア開発において極めて重要な役割を担っており、様々なアプリケーションやサービスで利用されています。
#
# 今回取り上げる楽天APIを利用すれば、ホテルの価格比較サイトなどで活用することが可能です。

# %% [markdown]
# ### 3.2.実際にやる事

# %% [markdown]
# SimpleHotelSearchにアクセスして、沖縄の那覇市のホテル情報を取得します。

# %% [markdown]
# <img src="img/img032.jpg">

# %% [markdown]
# 参照：https://www.ebisumart.com/blog/ec-api/

# %%
#ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。
import requests

# アクセス先と認証と要求するデータの内容を指定します。
REQUEST_URL = "https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426"
 #アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
APP_ID = "1090380199694035412"
# アクセス先と認証を用意できたので、なんのデータが欲しいかをparamsに代入しておきます。
# paramsでの指定方法はAPIの作成者によって変わりますので、事前に確認しておく必要があります。
params = {
    'format': 'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': '1090380199694035412'
}

# アクセス先と認証と要求するデータの内容を指定出来たので、requestsのgetメソッドを使ってアクセスします。
# その結果をresに代入します。
res = requests.get(REQUEST_URL, params)

# 欲しいデータはresのjsonに格納されているので、res.json()をresultに代入しておきましょう。
# これでAPIで取得したデータはresultに代入されます。
result = res.json()

# %%
# 実際にresultに格納されたデータを見てみましょう。
result
# Out:
# {'pagingInfo': {'recordCount': 416,
#   'pageCount': 14,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 182884,
#       'hotelName': 'ホテルリソルトリニティ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182884',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182884',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884',
#       'hotelKanaName': 'ほてるりぞるとりにてぃなは',
#       'hotelSpecial': '2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。',
#       'hotelMinCharge': 4200,
#       'latitude': 94341.93,
#       'longitude': 459641.13,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町7',
#       'telephoneNo': '098-863-9269',
#       'faxNo': '098-863-9279',
#       'access': 'ゆいレール「旭橋駅」出入口2より徒歩3分',
#       'parkingInformation': '機械式立体駐車場50台1泊1,500円 ※台風・災害時など利用不可※先着順予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182884.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884map.gif',
#       'reviewCount': 243,
#       'reviewAverage': 4.4,
#       'userReview': 'あまり広いお部屋ではないですが、木を基調とした柔らかい雰囲気で清潔感があり、とても居心地がよかったです。大浴場は、タイルが光に当たるととても綺麗で、旅の疲れが癒やされました。とにかく内装がとて…\u30002023-10-12 11:47:19投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.14,
#       'locationAverage': 4.39,
#       'roomAverage': 4.38,
#       'equipmentAverage': 4.21,
#       'bathAverage': 4.28,
#       'mealAverage': 4.37}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 128440,
#       'hotelName': 'ダイワロイネットホテル那覇国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=128440',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=128440&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=128440',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440',
#       'hotelKanaName': 'だいわろいねっと\u3000なはこくさいどおり',
#       'hotelSpecial': '国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪',
#       'hotelMinCharge': 3830,
#       'latitude': 94369.8,
#       'longitude': 459703.77,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2-1-1',
#       'telephoneNo': '098-868-9055',
#       'faxNo': '098-868-9056',
#       'access': 'ゆいレール「牧志」駅直結！！那覇空港からモノレールで約20分♪',
#       'parkingInformation': '当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/128440.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440_sin.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/128440.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440map.gif',
#       'reviewCount': 1465,
#       'reviewAverage': 4.37,
#       'userReview': 'まず立地が抜群に良いです。天気悪くてもゆいレール牧志駅から屋根付きの連絡通路があり安心です。国際通りが出て目の前ですので便利です。部屋は上層階の角部屋でした。長めも良く、部屋もクイーンベッド？…\u30002023-10-03 14:21:44投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.13,
#       'locationAverage': 4.76,
#       'roomAverage': 4.28,
#       'equipmentAverage': 4.03,
#       'bathAverage': 3.63,
#       'mealAverage': 4.36}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 134763,
#       'hotelName': 'ダイワロイネットホテル那覇おもろまち',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=134763',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=134763',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763',
#       'hotelKanaName': 'だいわろいねっとほてるなはおもろまち',
#       'hotelSpecial': '海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎',
#       'hotelMinCharge': 3800,
#       'latitude': 94389.24,
#       'longitude': 459709.57,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち1-1-12',
#       'telephoneNo': '098-862-4555',
#       'faxNo': '098-862-4556',
#       'access': 'ゆいレール\u3000おもろまち駅より徒歩５分\u3000国際通りより車で5分',
#       'parkingInformation': '1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用下さい。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/134763.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763_tw.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/134763.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763map.gif',
#       'reviewCount': 997,
#       'reviewAverage': 4.49,
#       'userReview': '初めて利用しました非常に清潔、快適で素晴らしかったですまた利用したいホテルです\u30002023-10-14 14:58:11投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.23,
#       'locationAverage': 4.28,
#       'roomAverage': 4.55,
#       'equipmentAverage': 4.23,
#       'bathAverage': 3.93,
#       'mealAverage': 4.12}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 148000,
#       'hotelName': 'ハイアットリージェンシー那覇沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=148000',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=148000&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=148000',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=148000',
#       'hotelKanaName': 'はいあっとりーじぇんしーなはおきなわ',
#       'hotelSpecial': 'グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。',
#       'hotelMinCharge': 7926,
#       'latitude': 94357.69,
#       'longitude': 459690.88,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-6-20',
#       'telephoneNo': '098-866-8888',
#       'faxNo': '098-866-8111',
#       'access': '那覇空港から車で約２０分、ゆいレール「牧志駅」から徒歩７分 、国際通りまで徒歩3分',
#       'parkingInformation': '立体駐車場・地下駐車場完備\u3000１１３台\u30001泊1台あたり1,500円（税込）\u3000（予約不要／出し入れ自由）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/148000.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000_kan.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/148000.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000map.gif',
#       'reviewCount': 633,
#       'reviewAverage': 4.64,
#       'userReview': 'クラブアクセス付きにして大正解。お部屋も綺麗で快適でした。対応していただいたスタッフの皆様に感謝します。ありがとうございました。\u30002023-09-23 15:27:19投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.65,
#       'locationAverage': 4.55,
#       'roomAverage': 4.71,
#       'equipmentAverage': 4.66,
#       'bathAverage': 4.19,
#       'mealAverage': 4.56}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 16443,
#       'hotelName': 'ロワジールホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=16443',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=16443&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=16443',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443',
#       'hotelKanaName': 'ろわじーるほてるなは',
#       'hotelSpecial': '空港から車で約7分。天然温泉大浴場、室内外プールと館内施設が充実♪■楽天認定プレミアムホテル■',
#       'hotelMinCharge': 5142,
#       'latitude': 94355.14,
#       'longitude': 459603.97,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1台1,800円',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/16443.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/16443.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443map.gif',
#       'reviewCount': 1351,
#       'reviewAverage': 3.93,
#       'userReview': '沖縄のリーズナブルなホテルは総じてですが、大浴場はそこまでよくありません。が、十分疲れが取れるレベルです。ご飯は種類も多く、とてもおいしいです。部屋はスーツケースをギリギリ開ける大きさですが、立地…\u30002023-10-10 16:40:56投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.72,
#       'locationAverage': 3.81,
#       'roomAverage': 3.82,
#       'equipmentAverage': 3.73,
#       'bathAverage': 3.88,
#       'mealAverage': 3.87}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181785,
#       'hotelName': 'ヒューイットリゾート那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181785',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181785&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181785',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785',
#       'hotelKanaName': 'ひゅーいっとりぞーとなは',
#       'hotelSpecial': '2021年7月15日OPEN！朝食ブッフェは宿泊の皆様に無料でご提供いたします！',
#       'hotelMinCharge': 5110,
#       'latitude': 94371.18,
#       'longitude': 459711.73,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2丁目5番16号',
#       'telephoneNo': '098-943-8325',
#       'faxNo': '098-943-8326',
#       'access': 'モノレール安里駅から徒歩3分\u3000バス国内線旅客ターミナル発120番安里下車徒歩3分\u3000タクシー那覇空港より約20分',
#       'parkingInformation': '有り\u300084台\u30001,650円（税込）/泊',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181785.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785map.gif',
#       'reviewCount': 270,
#       'reviewAverage': 4.29,
#       'userReview': '高級宿の表記もあり、口コミを見て予約しましたが見た目綺麗なビジネスホテルという感じでした。枕やシーツに髪の毛が数本落ちておりとても気になりました。部屋の温度も寒く、部屋のリモコンで…\u30002023-10-06 19:15:47投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.02,
#       'locationAverage': 4.5,
#       'roomAverage': 4.25,
#       'equipmentAverage': 3.96,
#       'bathAverage': 3.98,
#       'mealAverage': 4.21}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 104526,
#       'hotelName': 'ダイワロイネットホテル沖縄県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=104526',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=104526&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=104526',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=104526',
#       'hotelKanaName': 'だいわろいねっとほてるおきなわけんちょうまえ',
#       'hotelSpecial': '那覇空港より１５分。県庁等官庁街へ徒歩２分、人気の国際通りへは徒歩３分でビジネス・観光に好立地。',
#       'hotelMinCharge': 4500,
#       'latitude': 94353.12,
#       'longitude': 459642.44,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-2',
#       'telephoneNo': '098-860-1855',
#       'faxNo': '098-860-1856',
#       'access': '◆モノレール県庁前駅または旭橋駅 徒歩3分\u3000◆那覇空港 モノレール13分、車で約10分\u3000◆沖縄県庁、国際通り 徒歩3分',
#       'parkingInformation': '有り\u3000１台\u3000１０５０円（税込み／泊）\u3000先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/104526.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/104526.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526map.gif',
#       'reviewCount': 1152,
#       'reviewAverage': 4.19,
#       'userReview': '近くにコンビニもあり、助かります。モノレールも近いので、空港へのアクセスもいいです。デスクが大きく、仕事もしやすかったです。\u30002023-10-11 11:23:21投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.87,
#       'locationAverage': 4.32,
#       'roomAverage': 4.23,
#       'equipmentAverage': 3.9,
#       'bathAverage': 3.78,
#       'mealAverage': 3.41}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 177761,
#       'hotelName': '東急ステイ沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=177761',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=177761&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=177761',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761',
#       'hotelKanaName': 'とうきゅうすてい\u3000おきなわ\u3000なは',
#       'hotelSpecial': '食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチン完備！',
#       'hotelMinCharge': 5550,
#       'latitude': 94334.89,
#       'longitude': 459646.33,
#       'postalCode': '900-0025',
#       'address1': '沖縄県',
#       'address2': '那覇市壷川3-2-1',
#       'telephoneNo': '098-833-1090',
#       'faxNo': '098-833-1091',
#       'access': '沖縄都市モノレール線\u3000壷川駅より徒歩にて約３分',
#       'parkingInformation': '屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に料金発生',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177761.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761map.gif',
#       'reviewCount': 570,
#       'reviewAverage': 4.48,
#       'userReview': '立地がいい。下にドンキーがあるのもまたいいです。\u30002023-09-30 12:34:22投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.23,
#       'locationAverage': 4.52,
#       'roomAverage': 4.55,
#       'equipmentAverage': 4.28,
#       'bathAverage': 3.98,
#       'mealAverage': 4.33}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 167519,
#       'hotelName': 'ノボテル沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=167519',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=167519&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=167519',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519',
#       'hotelKanaName': 'のぼてる\u3000おきなわ\u3000なは',
#       'hotelSpecial': '国際通りから車で約５分、那覇にいてもリゾート気分を！クラブラウンジやインフィニティプールがあるホテル',
#       'hotelMinCharge': 5850,
#       'latitude': 94374.6,
#       'longitude': 459750.57,
#       'postalCode': '902-0062',
#       'address1': '沖縄県',
#       'address2': '那覇市松川40番地',
#       'telephoneNo': '098-887-1111',
#       'faxNo': '098-886-5591',
#       'access': '那覇空港から車で約25分、ゆいレール安里駅よりタクシーで約５分／徒歩約２０分',
#       'parkingInformation': '有り（1泊1台1,000円）\u3000※事前予約不可',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167519.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/167519.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519map.gif',
#       'reviewCount': 383,
#       'reviewAverage': 4.4,
#       'userReview': '綺麗なホテルでサービスも◎テラス付きの部屋にしました。素敵でした。テラスの椅子が少し汚れてたのと濡れてたので何か敷くものがあったら更に良かったです！ラウンジも素敵でよかったですし、サービス…\u30002023-09-10 09:49:34投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.39,
#       'locationAverage': 3.87,
#       'roomAverage': 4.35,
#       'equipmentAverage': 4.23,
#       'bathAverage': 4.08,
#       'mealAverage': 4.18}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 176757,
#       'hotelName': '沖縄ハーバービューホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=176757',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=176757&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=176757',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=176757',
#       'hotelKanaName': 'おきなわはーばーびゅーほてる',
#       'hotelSpecial': '楽天トラベルからのご予約限定☆楽天専用ラウンジOPEN☆お飲み物やアメニティをご用意しております',
#       'hotelMinCharge': 3375,
#       'latitude': 94336.98,
#       'longitude': 459657.29,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎2-46',
#       'telephoneNo': '098-853-2111',
#       'faxNo': '098-835-9696',
#       'access': '那覇空港より車で10分・ゆいレール壷川駅/旭橋駅より徒歩約10分/国際通りまで徒歩約10分',
#       'parkingInformation': '有り\u3000１９０台\u3000１８００円（税込み／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/176757.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/176757.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757map.gif',
#       'reviewCount': 483,
#       'reviewAverage': 4.27,
#       'userReview': '地元民です。クラブラウンジ付プランを利用しました。ゆっくりとホテルステイでき満足しています。次は遠方に住む両親と一緒に宿泊したいと思います。\u30002023-10-02 20:47:22投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.12,
#       'locationAverage': 3.84,
#       'roomAverage': 4.29,
#       'equipmentAverage': 4.07,
#       'bathAverage': 3.83,
#       'mealAverage': 4.13}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178447,
#       'hotelName': 'ＨＯＴＥＬ\u3000ＳＡＮＳＵＩ\u3000ＮＡＨＡ\u3000琉球温泉\u3000波之上の湯',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178447',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178447&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178447',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178447',
#       'hotelKanaName': 'ほてる\u3000さんすい\u3000なは\u3000りゅうきゅうおんせん\u3000なみのうえおんせん',
#       'hotelSpecial': '癒しの波上温泉とシースループール完備で那覇空港に一番近いスパ＆リゾート',
#       'hotelMinCharge': 4386,
#       'latitude': 94372.73,
#       'longitude': 459616.75,
#       'postalCode': '900-0037',
#       'address1': '沖縄県',
#       'address2': '那覇市辻2-25-1',
#       'telephoneNo': '0120-996-941',
#       'faxNo': '098-894-7303',
#       'access': '空港から車で約8分◆ホテルと那覇空港を結ぶシャトルバスも運行中◆崖の上の「縁結びパワースポット」波上宮まで【徒歩4分】',
#       'parkingInformation': '有り\u300042台\u30001,500円（税込み／泊）\u3000先着順\u3000※高さ制限有（175センチ）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178447.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447map.gif',
#       'reviewCount': 259,
#       'reviewAverage': 4.14,
#       'userReview': '朝食が沢山あり、どれも美味しかったです。\u30002023-10-06 22:45:55投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.94,
#       'locationAverage': 3.35,
#       'roomAverage': 3.91,
#       'equipmentAverage': 3.96,
#       'bathAverage': 4.2,
#       'mealAverage': 4.29}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 71990,
#       'hotelName': 'ホテル\u3000ロコア\u3000ナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=71990',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=71990&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=71990',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990',
#       'hotelKanaName': 'ろこあ\u3000なは',
#       'hotelSpecial': '目の前が国際通り！空港直通ゆいレール駅から徒歩2分！朝食バイキングは口コミでも高評価♪',
#       'hotelMinCharge': 4600,
#       'latitude': 94354.63,
#       'longitude': 459657.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-1-2',
#       'telephoneNo': '098-868-6578',
#       'faxNo': '098-868-6521',
#       'access': 'モノレール\u3000県庁前駅より徒歩２分',
#       'parkingInformation': '提携駐車場１泊1台１5００円。営業時間外の入出庫不可。先着順。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/71990.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/71990.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990map.gif',
#       'reviewCount': 1742,
#       'reviewAverage': 4.36,
#       'userReview': '朝食がとにかくおいしいです。沖縄のいろいろな特産物があり、品数も豊富です。デザートのフルーツ類がめちゃくちゃ美味しかったです。また、泊まりたいです。\u30002023-10-14 17:32:25投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.18,
#       'locationAverage': 4.71,
#       'roomAverage': 4.16,
#       'equipmentAverage': 4.02,
#       'bathAverage': 3.61,
#       'mealAverage': 4.45}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 163087,
#       'hotelName': 'ホテルアクアチッタナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=163087',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=163087&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=163087',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=163087',
#       'hotelKanaName': 'ほてるあくあちったなは',
#       'hotelSpecial': 'シースループール◆那覇の夜景を望めるナイトプールが人気◆地中海の朝市をコンセプトにした朝食',
#       'hotelMinCharge': 4464,
#       'latitude': 94385.53,
#       'longitude': 459666.2,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-2-20',
#       'telephoneNo': '0120-996-941',
#       'faxNo': '098-866-5600',
#       'access': '泊港離島ターミナルより徒歩30秒/美栄橋駅より徒歩7分/国際通りより徒歩約10分/那覇空港より車で約15分/国道58号沿',
#       'parkingInformation': '有 60台 1,200円（税込／泊）高さ制限1.55ｍ ※先着順\u3000その他のお車は近隣駐車場をご案内',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/163087.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/163087.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087map.gif',
#       'reviewCount': 354,
#       'reviewAverage': 4.32,
#       'userReview': '全体的に綺麗です。フロント対応も良くてまた使いたいと思います。\u30002023-10-09 10:12:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.05,
#       'locationAverage': 4.17,
#       'roomAverage': 4.14,
#       'equipmentAverage': 4,
#       'bathAverage': 3.8,
#       'mealAverage': 4.5}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178292,
#       'hotelName': 'ホテル\u3000ストレータ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292',
#       'hotelKanaName': 'すとれーたなは',
#       'hotelSpecial': '「美栄橋」から、新しい沖縄らしさを育み、発信していく場所となっていくことを目指しています。',
#       'hotelMinCharge': 4250,
#       'latitude': 94373.92,
#       'longitude': 459670.45,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志1丁目19番8号',
#       'telephoneNo': '098-860-7400',
#       'faxNo': '098-860-7410',
#       'access': 'ゆいレール「美栄橋駅」より徒歩30秒｜那覇空港より車で約16分｜国際通りまで徒歩約5分',
#       'parkingInformation': '立体駐車場48台：\\1,500/1泊\u3000到着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178292.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292map.gif',
#       'reviewCount': 205,
#       'reviewAverage': 4.45,
#       'userReview': '駅近なので移動に困りません。駐車場は立体なので大きな荷物はエントランスで荷下ろしがベスト。タオルは人数分のみなので、大きなバスタブで複数回の入浴はタオルの追加を有料で手配できます。スイート…\u30002023-09-26 13:48:00投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.22,
#       'locationAverage': 4.89,
#       'roomAverage': 4.25,
#       'equipmentAverage': 4.04,
#       'bathAverage': 3.77,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 149369,
#       'hotelName': 'ホテルグレイスリー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=149369',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=149369&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=149369',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=149369',
#       'hotelKanaName': 'ぐれいすりーなは',
#       'hotelSpecial': '★国際通り徒歩0分！★バス・トイレ別で、観光・出張も快適に♪焼きたてあぐー豚が人気の朝食ビュッフェ',
#       'hotelMinCharge': 5000,
#       'latitude': 94356.9,
#       'longitude': 459663.7,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-3-6',
#       'telephoneNo': '098-867-6111',
#       'faxNo': '098-867-4311',
#       'access': '●ゆいレール「県庁前」駅徒歩5分／●「国際通り」徒歩0分。荷物が多くても、車が無くても楽々♪',
#       'parkingInformation': '近隣（徒歩5分ほど）のコインパーキングをご案内します。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/149369.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/149369.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369map.gif',
#       'reviewCount': 592,
#       'reviewAverage': 4.5,
#       'userReview': '食事は外で頂く予定だったので、お部屋だけで宿泊しましたが立地も含めて大満足です(^^)また、行く時はお世話になりたいと思います。\u30002023-10-12 18:58:55投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.3,
#       'locationAverage': 4.71,
#       'roomAverage': 4.38,
#       'equipmentAverage': 4.11,
#       'bathAverage': 4.53,
#       'mealAverage': 4.36}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 136808,
#       'hotelName': 'リーガロイヤルグラン沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=136808',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=136808&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=136808',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808',
#       'hotelKanaName': 'りーがろいやるぐらんおきなわ',
#       'hotelSpecial': '【エントリーと予約でポイント増量参画中】「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド',
#       'hotelMinCharge': 7466,
#       'latitude': 94344.0,
#       'longitude': 459638.85,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町1-9',
#       'telephoneNo': '098-867-3331',
#       'faxNo': '098-867-3332',
#       'access': '【那覇空港から】車で約５分、ゆいレール「旭橋駅」下車\u3000駅から直結 【那覇バスターミナル】徒歩２分 【国際通り】徒歩１０分',
#       'parkingInformation': '有り\u3000料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/136808.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/136808.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808map.gif',
#       'reviewCount': 615,
#       'reviewAverage': 4.67,
#       'userReview': '今回初めて利用しましたが、ラグジュアリー感、清潔感、部屋も綺麗で最高でした!!スタッフさんの対応も良く、親切にして頂きありがとうございました!!お部屋のバスタブがとにかく良かったです。また那覇に宿泊す…\u30002023-09-30 13:22:14投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.58,
#       'locationAverage': 4.74,
#       'roomAverage': 4.52,
#       'equipmentAverage': 4.66,
#       'bathAverage': 4.61,
#       'mealAverage': 4.43}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 18195,
#       'hotelName': 'サンプラザホテル＜沖縄県＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=18195',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=18195&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=18195',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195',
#       'hotelKanaName': 'さんぷらざほてる＜おきなわけん＞',
#       'hotelSpecial': 'ゆいレール牧志駅から徒歩5分。那覇のメインストリート国際通り近く、大浴場・コインランドリー有。',
#       'hotelMinCharge': 2000,
#       'latitude': 94378.86,
#       'longitude': 459694.79,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里138',
#       'telephoneNo': '098-866-0920',
#       'faxNo': '098-866-0929',
#       'access': '那覇空港から車で約15分・モノレール牧志駅から徒歩5分・崇元寺バス停前徒歩0分',
#       'parkingInformation': '有り\u3000先着順40台予約不可￥1000/泊※バス・大型車などの駐車は電話でお問合せ下さい。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/18195.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195_y.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/18195.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195map.gif',
#       'reviewCount': 2751,
#       'reviewAverage': 4.14,
#       'userReview': '1人なのにツインの洋室と和室のある広い部屋でした。大浴場は快適でサッパリしました。部屋にドライヤーが無い事だけが残念でしたが、朝食付きでこの価格は非常にリーズナブルだと思います。\u30002023-10-08 12:57:59投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.08,
#       'locationAverage': 4.22,
#       'roomAverage': 3.78,
#       'equipmentAverage': 3.56,
#       'bathAverage': 4.12,
#       'mealAverage': 3.81}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 38282,
#       'hotelName': 'ホテルパームロイヤルNAHA国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=38282',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=38282&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=38282',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282',
#       'hotelKanaName': 'ぱーむろいやる\u3000なは\u3000こくさいどおり',
#       'hotelSpecial': '＼国際通りから一歩入ると現れる楽園／ナノ水ロイヤルスパや朝食KUNCHIめしも人気',
#       'hotelMinCharge': 4100,
#       'latitude': 94365.08,
#       'longitude': 459689.04,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-9-10',
#       'telephoneNo': '098-865-5551',
#       'faxNo': '098-866-7711',
#       'access': '【ゆいレール】牧志駅下車徒歩4分（那覇空港から約25分）／【車】那覇空港より車で約15分\u3000',
#       'parkingInformation': '【有り：60台】1泊1100円（税込）満車の場合は近隣のコインパーキングをご利用下さい。※先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/38282.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/38282.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282map.gif',
#       'reviewCount': 2273,
#       'reviewAverage': 4.31,
#       'userReview': 'ビジネス利用ではありますが、定期的にこちらにお世話になっています。周辺にはハイアットやJR九州ホテル、JALシティなどのラグジュアリー系のホテルもありますが、やはりアットホーム感や柔軟性、カジュア…\u30002023-10-03 21:18:06投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.36,
#       'locationAverage': 4.79,
#       'roomAverage': 4.19,
#       'equipmentAverage': 4.2,
#       'bathAverage': 4.31,
#       'mealAverage': 4.23}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 171943,
#       'hotelName': '沖縄かりゆしリゾートエグゼス那覇＜県庁前＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=171943',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=171943&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=171943',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943',
#       'hotelKanaName': 'おきなわ\u3000かりゆし\u3000りぞーと\u3000えぐぜす\u3000なは',
#       'hotelSpecial': '那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）',
#       'hotelMinCharge': 8920,
#       'latitude': 94353.21,
#       'longitude': 459643.86,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-5',
#       'telephoneNo': '098-860-3300',
#       'faxNo': '098-860-3450',
#       'access': '那覇空港から車で約10分。モノレールご利用の場合は那覇空港駅→県庁前駅13分、下車、徒歩約4分。',
#       'parkingInformation': '有り\u3000４２台\u3000１５００円（税込／泊）\u3000満車の場合は周辺のコインパーキングをご利用くださいませ。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/171943.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943map.gif',
#       'reviewCount': 112,
#       'reviewAverage': 4.61,
#       'userReview': '前回同様プール付きの部屋を利用しました。観光目的ではなく部屋でのんびりするためにお世話になりました。朝食の片付けタイミングがスタッフによって違い、前回利用した際に、男性スタッフの方がチャイムを鳴らして…\u30002023-09-15 17:27:22投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.56,
#       'locationAverage': 4.58,
#       'roomAverage': 4.67,
#       'equipmentAverage': 4.43,
#       'bathAverage': 4.48,
#       'mealAverage': 4.62}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 130025,
#       'hotelName': '西鉄リゾートイン那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=130025',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=130025&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=130025',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=130025',
#       'hotelKanaName': 'にしてつりぞーといんなは',
#       'hotelSpecial': 'ゆいレール県庁前駅から徒歩３分。歩いて国際通りへ、便利なアクセス♪',
#       'hotelMinCharge': 4200,
#       'latitude': 94361.44,
#       'longitude': 459645.53,
#       'postalCode': '900-0033',
#       'address1': '沖縄県',
#       'address2': '那覇市久米2-3-13',
#       'telephoneNo': '098-869-5454',
#       'faxNo': '098-869-5455',
#       'access': '那覇空港からゆいレールで6駅目「県庁前駅」から徒歩約3分！国道58号沿い、国際通りへ徒歩5分！繁華街「松山」まで徒歩5分',
#       'parkingInformation': '有り４０台（先着順）１，２００円/泊。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/130025.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025_rm1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/130025.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025map.gif',
#       'reviewCount': 809,
#       'reviewAverage': 4.32,
#       'userReview': 'エアコンの温度調整に苦労しました。\u30002023-10-10 08:31:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.1,
#       'locationAverage': 4.62,
#       'roomAverage': 4.14,
#       'equipmentAverage': 3.94,
#       'bathAverage': 4.04,
#       'mealAverage': 4.05}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 67292,
#       'hotelName': 'アパホテル〈那覇〉',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=67292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=67292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=67292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=67292',
#       'hotelKanaName': 'あぱほてる\u3000なは',
#       'hotelSpecial': '沖縄最大の繁華街奇跡の1マイルと評される「国際通り」徒歩9分、疲れた体は大浴場（無料）で癒せます',
#       'hotelMinCharge': 3600,
#       'latitude': 94371.2,
#       'longitude': 459655.92,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山1-4-16',
#       'telephoneNo': '098-868-9111',
#       'faxNo': '098-868-9411',
#       'access': '那覇空港から車で最短10分、ゆいレール（モノレール）「県庁前」または「美栄橋」駅から徒歩約7分 新都心へは車で10分',
#       'parkingInformation': '立体駐車場先着順46台1泊1,500円 【車高1.8m制限有】※新規入庫は23時迄\u3000',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/67292.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292_yo.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/67292.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292map.gif',
#       'reviewCount': 2538,
#       'reviewAverage': 3.97,
#       'userReview': 'よかった\u30002023-10-08 13:05:45投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.96,
#       'locationAverage': 4.26,
#       'roomAverage': 3.67,
#       'equipmentAverage': 3.8,
#       'bathAverage': 3.77,
#       'mealAverage': 4.1}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 19934,
#       'hotelName': 'リッチモンドホテル那覇久茂地',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=19934',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=19934&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=19934',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=19934',
#       'hotelKanaName': 'りっちもんど\u3000なは\u3000くもじ',
#       'hotelSpecial': '国際通りやケラマ諸島へのアクセス泊港へも徒歩でOK◎美栄橋駅より徒歩２分☆1階セブンイレブンが便利',
#       'hotelMinCharge': 3170,
#       'latitude': 94378.89,
#       'longitude': 459664.07,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地2-23-12',
#       'telephoneNo': '098-869-0077',
#       'faxNo': '098-862-0088',
#       'access': '那覇空港より沖縄都市モノレール（ゆいレール）１４分、美栄橋(みえばし)駅下車徒歩約２分\u3000国道５８号線前島交差点沿い',
#       'parkingInformation': '立体駐車場(車高2ｍ)1泊 1台1,000円 ※先着順でご利用いただけます(予約制ではございません)',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/19934/19934.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/19934.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/19934/19934map.gif',
#       'reviewCount': 3681,
#       'reviewAverage': 4.18,
#       'userReview': '大満足です。朝食美味しかったです。また利用したいです。\u30002023-10-03 18:38:52投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.89,
#       'locationAverage': 4.15,
#       'roomAverage': 4.13,
#       'equipmentAverage': 3.71,
#       'bathAverage': 3.52,
#       'mealAverage': 4.08}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 40768,
#       'hotelName': 'アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=40768',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=40768&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=40768',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=40768',
#       'hotelKanaName': 'あるもんとほてるなはおもろまち',
#       'hotelSpecial': '２０２０年４月１日から『アルモントホテル那覇おもろまち』へリブランド',
#       'hotelMinCharge': 3700,
#       'latitude': 94395.88,
#       'longitude': 459713.63,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち4-3-8',
#       'telephoneNo': '098-860-6611',
#       'faxNo': '098-860-6711',
#       'access': 'ゆいレール「おもろまち駅」下車徒歩4分／Tギャラリア沖縄まで徒歩4分／サンエー那覇メインプレイス向い',
#       'parkingInformation': '有り\u300030台\u30001,100円（税込／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/40768.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/40768.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768map.gif',
#       'reviewCount': 1512,
#       'reviewAverage': 4.54,
#       'userReview': '朝食が美味しいホテルだと口コミがあったので宿泊しました。とても美味しかったです！エレベーター内はいい匂いがしていたのですが、お部屋が若干カビ臭くて...備え付けのスプレーしても効果なし…\u30002023-10-08 18:34:14投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=40768" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.35,
#       'locationAverage': 4.51,
#       'roomAverage': 4.13,
#       'equipmentAverage': 4.13,
#       'bathAverage': 4.32,
#       'mealAverage': 4.84}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 78094,
#       'hotelName': 'ロワジールスパタワー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=78094',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=78094&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=78094',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094',
#       'hotelKanaName': 'ろわじーるすぱたわーなは',
#       'hotelSpecial': '天然温泉を24時間楽しめる客室有！全室バルコニー付、24時間利用できるフィットネスジム完備',
#       'hotelMinCharge': 7968,
#       'latitude': 94353.28,
#       'longitude': 459606.91,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1,800円/台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/78094.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/78094.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094map.gif',
#       'reviewCount': 480,
#       'reviewAverage': 3.96,
#       'userReview': '部屋に入る前から嫌な思いばかりでした。まずチェックイン前の時間に到着して行列、1時間近く並びました。さすがに怒りましたが、さらにチェックイン時にも部屋の準備ができてないので待っててくれと。部屋の前…\u30002023-09-20 11:17:46投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.79,
#       'locationAverage': 3.77,
#       'roomAverage': 4,
#       'equipmentAverage': 4.2,
#       'bathAverage': 4.47,
#       'mealAverage': 3.92}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 43753,
#       'hotelName': 'ソルヴィータホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=43753',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=43753&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=43753',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=43753',
#       'hotelKanaName': 'そるう゛ぃーたほてるなは',
#       'hotelSpecial': '宿泊者専用ラウンジあり、アイスやドリンクあり。小学生まで添い寝利用可！タオルやキッズアメニティ無料！',
#       'hotelMinCharge': 3450,
#       'latitude': 94376.95,
#       'longitude': 459651.54,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山2丁目17-17',
#       'telephoneNo': '098-863-1234',
#       'faxNo': '098-863-6911',
#       'access': '那覇空港より車で約8分ゆいレール県庁前駅・美栄橋駅・パレット久茂地より徒歩約10分！泊港（とまりん）より徒歩約5分！',
#       'parkingInformation': '有り\u300040台（1500円／泊  ）先着順・予約不可\u3000平面駐車場で出し入れラクラク',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/43753.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753_kya1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/43753.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753map.gif',
#       'reviewCount': 1648,
#       'reviewAverage': 4.5,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 160939,
#       'hotelName': 'ＪＲ九州ホテル\u3000ブラッサム那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=160939',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=160939&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=160939',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939',
#       'hotelKanaName': 'じぇいあーるきゅうしゅうほてる\u3000ぶらっさむなは',
#       'hotelSpecial': '国際通りむつみ橋交差点徒歩1分。ゆいレール美栄橋駅徒歩５分。',
#       'hotelMinCharge': 7200,
#       'latitude': 94367.2,
#       'longitude': 459682.25,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2丁目16番１号',
#       'telephoneNo': '098-861-8700',
#       'faxNo': '098-862-8739',
#       'access': '那覇空港よりタクシーで約15分、ゆいレール\u3000美栄橋駅より徒歩にて約５分',
#       'parkingInformation': '有り\u3000１１２台\u3000１５００円（税込み／泊）\u3000予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/160939.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/160939.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939map.gif',
#       'reviewCount': 419,
#       'reviewAverage': 4.38,
#       'userReview': '雨の日は無料の傘を貸し出しされているので助かりました。部屋のホコリが落ちて掃除をしました。どこも人手不足なのでよしとしましょう。立地場所はお気に入りなので、また今度も宿泊したいです。\u30002023-10-11 13:10:06投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.07,
#       'locationAverage': 4.67,
#       'roomAverage': 4.46,
#       'equipmentAverage': 4.16,
#       'bathAverage': 4.44,
#       'mealAverage': 4.11}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 184913,
#       'hotelName': 'Ｓｏｕｔｈｗｅｓｔ\u3000Ｇｒａｎｄ\u3000Ｈｏｔｅｌ（２０２３年６月２０日新規開業）',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=184913',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=184913&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=184913',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=184913',
#       'hotelKanaName': 'さうすうえすとぐらんどほてる',
#       'hotelSpecial': '【2023年6月開業！】楽天限定開業記念プラン販売中！',
#       'hotelMinCharge': 13750,
#       'latitude': 94361.9,
#       'longitude': 459667.77,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地3-29-52',
#       'telephoneNo': '098-860-0421',
#       'faxNo': '098-860-0411',
#       'access': '・ゆいレールご利用：「県庁前」駅から徒歩約5分\u3000・タクシーご利用：那覇空港から約12分',
#       'parkingInformation': 'あり\u300010台\u30001500円（税込／泊）\u3000先着順\u3000※満車の場合は近隣のコインパーキングをご利用ください',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184913/184913.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/184913.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184913/184913map.gif',
#       'reviewCount': 6,
#       'reviewAverage': 4.33,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181957,
#       'hotelName': 'ＯＭＯ５沖縄那覇\u3000ｂｙ\u3000星野リゾート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181957',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181957&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181957',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957',
#       'hotelKanaName': 'おも５\u3000おきなわなは\u3000ばい\u3000ほしのりぞーと',
#       'hotelSpecial': '国際通りから徒歩8分の好アクセス★寝るだけでは終わらせない、旅のテンションをあげるホテル',
#       'hotelMinCharge': 3200,
#       'latitude': 94368.45,
#       'longitude': 459654.1,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山１丁目3-16',
#       'telephoneNo': '05031348095',
#       'faxNo': '098-869-3787',
#       'access': '県庁前駅より徒歩6分、美栄橋駅より徒歩8分。那覇空港より車8分で国際通り至近',
#       'parkingInformation': '立体駐車場44台（1泊￥1500・車高1.9Mまで）先着順10:00PM〜6:00AMは入出庫不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181957.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957map.gif',
#       'reviewCount': 90,
#       'reviewAverage': 4.26,
#       'userReview': 'お部屋の雰囲気もよく、国際通りからもアクセスしやすく大変良かったです。近くにコンビニもあり、すぐに買い出しに行くこともできました。チェックアウトも自身ですぐに行うことができ、待ち時間もなくスムーズに使…\u30002023-10-14 11:44:56投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.97,
#       'locationAverage': 4.14,
#       'roomAverage': 4.28,
#       'equipmentAverage': 3.83,
#       'bathAverage': 3.48,
#       'mealAverage': 4.18}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 73870,
#       'hotelName': 'コンフォートホテル那覇県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=73870',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=73870&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=73870',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=73870',
#       'hotelKanaName': 'こんふぉーとほてるなはけんちょうまえ',
#       'hotelSpecial': 'モノレール県庁前駅徒歩３分◆国際通り徒歩3分◆無料朝食◆小学生まで添い寝無料◆全室禁煙Wi-Fi対応',
#       'hotelMinCharge': 3750,
#       'latitude': 94354.31,
#       'longitude': 459645.66,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地1-3-11',
#       'telephoneNo': '098-941-7311',
#       'faxNo': '098-941-7312',
#       'access': 'モノレール（ゆいレール）県庁前駅徒歩３分◆那覇空港モノレール１３分・車１０分◆沖縄県庁、国際通り徒歩３分',
#       'parkingInformation': '1泊820円（15：00〜翌12：00）敷地内駐車場5台',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/73870.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870_sig.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/73870.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870map.gif',
#       'reviewCount': 2807,
#       'reviewAverage': 4.24,
#       'userReview': '部屋が綺麗で良かった。\u30002023-10-12 07:07:20投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.16,
#       'locationAverage': 4.61,
#       'roomAverage': 4.07,
#       'equipmentAverage': 3.74,
#       'bathAverage': 3.35,
#       'mealAverage': 3.82}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 76923,
#       'hotelName': '那覇東急ＲＥＩホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=76923',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=76923&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=76923',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=76923',
#       'hotelKanaName': 'なはとうきゅうＲＥＩ',
#       'hotelSpecial': '那覇空港や国際通りからすぐの市内中心地にあり、ビジネス・レジャーに最適！',
#       'hotelMinCharge': 4370,
#       'latitude': 94340.7,
#       'longitude': 459644.78,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町116-37（「カフーナ旭橋」内、自治会館隣）',
#       'telephoneNo': '098-869-0109',
#       'faxNo': '098-869-0179',
#       'access': '空港からホテル約15分/ゆいレール「旭橋駅」から連絡通路直結/国際通り入口徒歩約10分/那覇バスターミナル徒歩約3分',
#       'parkingInformation': 'カフーナ旭橋駐車場“E棟”(ホテル向かい)\u3000約100台\u30001泊最大1,500円(15時〜翌日10時)',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/76923.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/76923.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923map.gif',
#       'reviewCount': 1218,
#       'reviewAverage': 4.32,
#       'userReview': '駅直結なので空港ついてからホテルまでスムーズに移動できました。とにかく安かったのでそこまでクオリティを気にしていませんでしたが、部屋内は綺麗だし、アメニティも充実してました。またぜひ予約したいです。\u30002023-10-05 20:13:18投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.18,
#       'locationAverage': 4.52,
#       'roomAverage': 4.45,
#       'equipmentAverage': 4.06,
#       'bathAverage': 3.58,
#       'mealAverage': 4.05}}]}]}

# %% [markdown]
# ブラウザでもrequestsがアクセスしてる先をブラウザでも見てみましょう

# %%
# requestsがどんなURLでリクエストしたかをres.urlで確認出来ます。
res.url
# Out:
# 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?format=json&largeClassCode=japan&middleClassCode=okinawa&smallClassCode=nahashi&applicationId=1090380199694035412'

# %% [markdown]
# res.urlで出力したURLを整理してみると
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# format=json
# &largeClassCode=japan
# &middleClassCode=okinawa
# &smallClassCode=nahashi
# &applicationId=1011509919335500197
#
# となり、?の後ろ側にリクエストしたいパラメーターがついている事がわかります。

# %% [markdown]
# これは楽天トラベルに書いてある
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# applicationId=[アプリID]
# &format=xml
# &largeClassCode=japan
# &middleClassCode=akita
# &smallClassCode=tazawa
#
# と要求してるパラメータの順番が違うだけで、同じ事を要求の仕方をしているのがわかると思います！
#
# requestでは?の後ろのパラメータを

# %%
# paramの設定
params = {
    'format': 'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': '1090380199694035412'
}

# %% [markdown]
# という形で格納し、requests.get(REQUEST_URL, params)で１つのリクエスト付きURLにしています。

# %% [markdown]
# よってURLの後ろにあるパラメータとrequestsのparamsが同じ変数を指定している事がわかりますね！
#
# URL属性以外にもrequests.Responseクラスには以下のような属性がある（一部）。

# %% [markdown]
# | 属性 | 説明 |
# | --- | --- |
# | text | レスポンスの内容（content属性）を文字列にデコードしたもの |
# | content | レスポントの内容（バイト列）。テキスト表現ではなくバイナリデータを扱うときにはこちらを使用する |
# | encoding | content属性をtext属性にデコードする際に使用したエンコーディング |
# | apparent_encoding | https://pypi.org/project/charset-normalizer/もしくはhttps://pypi.org/project/chardet/によって推測されたエンコーディング。encoding属性の値とapparent_encoding属性の値が異なることもある |
# | headers | レスポンスヘッダーを大文字小文字の区別をしない辞書の形式で格納したもの |
# | url | リクエストしたURL。リダイレクトが発生した場合には、リダイレクト先のURL |
# | history | get関数でリクエストしたURLがリダイレクトされた場合に、リダイレクトされた結果を示すrequests.Responseクラスのインスタンスを古いものから順に並べたリスト |
# |  |  |

# %% [markdown]
# requests.Responseクラスのインスタンスが持つ属性（一部）
# 参照：https://atmarkit.itmedia.co.jp/ait/articles/2209/27/news035.html

# %% [markdown]
# では、http経由でデータを取得する所から演習しましょう。

# %% [markdown]
# ### 3.3.http経由でデータを取得

# %% [markdown]
# #### http通信のリクエストをしてみよう

# %% [markdown]
# リクエストをするためのライブラリをインポートしておきましょう！

# %%
#ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。
import requests

# %% [markdown]
# インポートすることによってrequestsの機能を使う事ができます。
# ではrequestsを使って、ブラウザのようにhtmlが取得できるかどうか確認してみましょう！
# requests.get("ここに接続したいサイトのURL")とすることでhtmlが取得できます。

# %% [markdown]
# <img src="img/img025.png">

# %% [markdown]
# 参照：https://www.itmanage.co.jp/column/about-http-https/

# %% [markdown]
# ブラウザと同じように取得できているかどうかは、ブラウザの検証機能にある、ページソース表示で確認できます！

# %%
#アクセスして取得したサイトデータをresに代入しておきます。今回はTech0のサイトにアクセス
res = requests.get('https://tech0-jp.com/')

# %%
#resに代入しておいたサイトデータprintでかくにんします。
print(res.text)

#これを得られた結果とブラウザのページソース表示で得られるhtmlを比較して、ブラウザと同じ機能であることを確認しましょう！
# Out:
# <!doctype html>
# <html lang="ja">
# <head>
# 	<meta charset="UTF-8">
# 	<meta property="og:type" content="website" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="twitter:card" content="summary_large_image">
# 	<meta name="twitter:title" content="ビジネスxテクノロジーで新しい価値を生み出せるテック人材へ">
# 	<meta property="og:description" content="ビジネスxテクノロジーで新しい価値を生み出せるテック人材へ" >
# 	<meta property="og:url" content="https://tech0-jp.com/">
# 	<meta property="og:site_name" content="Tech0">
# 	<meta property="og:locale" content="ja_JP">
# 	<meta property="og:title" content="Tech0">
# 	<meta property="og:image" content="https://tech0-jp.com/wp-content/uploads/2023/07/Tech0_OGP_v2.png" >
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
# 	<link rel="canonical" href="https://tech0-jp.com/">
#
# 	<title>Tech0</title>
# <meta name='robots' content='max-image-preview:large' />
# <link rel='dns-prefetch' href='//use.fontawesome.com' />
# <link rel="alternate" type="application/rss+xml" title="Tech0 &raquo; フィード" href="https://tech0-jp.com/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Tech0 &raquo; コメントフィード" href="https://tech0-jp.com/comments/feed/" />
# <link rel='stylesheet' id='wp-block-library-css' href='https://tech0-jp.com/wp-includes/css/dist/block-library/style.min.css?ver=6.3.2' media='all' />
# <style id='classic-theme-styles-inline-css'>
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id='global-styles-inline-css'>
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(.alignright):not(.alignfull)){max-width: var(--wp--style--global--content-size);margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignwide{max-width: var(--wp--style--global--wide-size);}body .is-layout-flex{display: flex;}body .is-layout-flex{flex-wrap: wrap;align-items: center;}body .is-layout-flex > *{margin: 0;}body .is-layout-grid{display: grid;}body .is-layout-grid > *{margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-colu ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <link rel='stylesheet' id='contact-form-7-css' href='https://tech0-jp.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.8.1' media='all' />
# <link rel='stylesheet' id='st-affiliate-manager-common-css' href='https://tech0-jp.com/wp-content/plugins/st-affiliate-manager/Resources/assets/css/common.css?ver=20201211' media='all' />
# <link rel='stylesheet' id='st-pv-monitor-shortcode-css' href='https://tech0-jp.com/wp-content/plugins/st-pv-monitor/Resources/assets/css/shortcode.css?ver=20201211' media='all' />
# <link rel='stylesheet' id='st-pv-monitor-common-css' href='https://tech0-jp.com/wp-content/plugins/st-pv-monitor/Resources/assets/css/common.css?ver=20201211' media='all' />
# <link rel='stylesheet' id='allwhite-style-css' href='https://tech0-jp.com/wp-content/themes/allallwhite/style.css?ver=1.0.0' media='all' />
# <link rel='stylesheet' id='font-awesome-official-css' href='https://use.fontawesome.com/releases/v6.1.2/css/all.css' media='all' integrity="sha384-fZCoUih8XsaUZnNDOiLqnby1tMJ0sE7oBbNk2Xxf5x8Z4SvNQ9j83vFMa/erbVrV" crossorigin="anonymous" />
# <link rel='stylesheet' id='font-awesome-official-v4shim-css' href='https://use.fontawesome.com/releases/v6.1.2/css/v4-shims.css' media='all' integrity="sha384-iW7MVRJO9Fj06GFbRcMqdZBcVQhjBWlVXUjtY7XCppA+DZUoHBQ7B8VB+EjXUkPV" crossorigin="anonymous" />
# <script src='https://tech0-jp.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.0' id='jquery-core-js'></script>
# <script src='https://tech0-jp.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.1' id='jquery-migrate-js'></script>
# <link rel="https://api.w.org/" href="https://tech0-jp.com/wp-json/" /><link rel="alternate" type="application/json" href="https://tech0-jp.com/wp-json/wp/v2/pages/505" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://tech0-jp.com/xmlrpc.php?rsd" />
# <meta name="generator" content="WordPress 6.3.2" />
# <link rel="canonical" href="https://tech0-jp.com/" />
# <link rel='shortlink' href='https://tech0-jp.com/' />
# <link rel="alternate" type="application/json+oembed" href="https://tech0-jp.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftech0-jp.com%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://tech0-jp.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftech0-jp.com%2F&#038;format=xml" />
# <!-- start Simple Custom CSS and JS -->
# <!-- Meta Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '733431301477159');
# // fbq('init', '668703764963307');
# fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=733431301477159&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Meta Pixel Code --><!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <!-- Hotjar Tracking Code for https://tech0-jp.com/ -->
# <script>
#   (function (h, o, t, j, a, r) {
#     h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#     if (location.pathname == "/ad/") {
#       h._hjSettings = { hjid: 3363725, hjsv: 6 };
#     } else {
#       h._hjSettings = { hjid: 3303283, hjsv: 6 };
#     };
#     a = o.getElementsByTagName("head")[0];
#     r = o.createElement("script");
#     r.async = 1;
#     r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#     a.appendChild(r);
#   })(window, document, "https://static.hotjar.com/c/hotjar-", ".js?sv=");
# </script><!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <script
#   src="https://code.jquery.com/jquery-3.6.3.min.js"
#   integrity="sha256-pvPw+upLPUjgMXY0G+8O0xUf+/Im1MZjXxxgOcBQBXU="
#   crossorigin="anonymous"
# ></script>
# <!-- Google tag (gtag.js) -->
# <script type="text/javascript">
#   jQuery(document).ready(function ($) {
#     if (location.pathname == "/ad/") {
#       $.ajax({
#         url: "https://www.googletagmanager.com/gtag/js?id=G-NR436CS4MH",
#         dataType: "script",
#         cache: false,
#         async: true,
#       }).then(function (response) {
#         console.log("done!");
#       });
#     } else {
#       $.ajax({
#         url: "https://www.googletagmanager.com/gtag/js?id=UA-172511782-2",
#         dataType: "script",
#         cache: false,
#         async: true,
#       }).then(function (response) {
#         console.log("done!!");
#       });
#     }
#   });
# </script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     dataLayer.push(arguments);
#   }
#   gtag("js", new Date());
#   if (location.pathname == "/ad/") {
#     gtag("config", "G-NR436CS4MH");
# 	console.log("done!");
#   } else {
#     gtag("config", "UA-172511782-2");
# 	console.log("done!!");
#   }
# </script><!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <meta name="facebook-domain-verification" content="9h2gunogdojq02175q414j2aot1g5c" />
# <meta name="google-site-verification" content="6aeR7jhFhbC8Ky8ZNOvceFI15589nIxYf-mDbs92mWA" /><!-- end Simple Custom CSS and JS -->
# 		<style type="text/css">
# 					.site-title,
# 			.site-description {
# 				position: absolute;
# 				clip: rect(1px, 1px, 1px, 1px);
# 				}
# 					</style>
# 		<link rel="icon" href="https://tech0-jp.com/wp-content/uploads/2022/09/logo-150x150.png" sizes="32x32" />
# <link rel="icon" href="https://tech0-jp.com/wp-content/uploads/2022/09/logo-300x300.png" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://tech0-jp.com/wp-content/uploads/2022/09/logo-300x300.png" />
# <meta name="msapplication-TileImage" content="https://tech0-jp.com/wp-content/uploads/2022/09/logo-300x300.png" />
# 		<style id="wp-custom-css">
# 			.page {
# 	margin:0!important;
# }
# .entry-content {
# 	margin-top:-16px;
# }
# body {
# 	position:relative;
# 	padding-bottom:264px;
# }
# :root {
#   --tech0-color1: #02bdd6;
#   --tech0-color2: #28385e;
#   --tech0-color3: #516c8d;
#   --tech0-color4: #d9d9d9;
#   --tech0-color5: rgba(18, 127, 205, 0.7);
#   --tech0-color6: #127fcd;
#   --tech0-color7: #deeff8;
#   --tech0-color8: #525252;
#   --content-width: 1440px;
# 	--circle-radius: 16.67vw;
#   --circle-radius-sm: 30.76vw;
# }
# .footer-div4 a {
# 	pointer-events:none;
# }
# .hero-p4sm a {
# 	color:#fff;
# }
#
# .margin-center {
#   margin-right: auto !important;
#   margin-left: auto !important;
# }
#
# * {
#  font-family: "Helvetica", "Noto Sans JP", sans-serif;
# }
#
# .strong {
#   font-weight: 900;
# }
#
# .ul-naviBar a {
#   color: inherit!important;
#   text-decoration: none!important;
#   cursor: pointer;
# }
# a {
# 	text-decoration: none!important;
# }
# .ul-naviBar a:hover {
#   color: inherit!important;
# }
# .a-active {
#   color: #808080;
#   border-bottom: 2px solid #808080;
#   pointer-events: none;
# }
#
# .content {
#   max-width: var(--content-width);
#   margin: 0 auto;
# }
#
#
#
#
#
# @media screen and (min-width: 960px) {
#   .ul-naviBar {
#     z-index: 10;
#     background-color: #fff;
#     align-items: center;
#
#     border-radius: 16px;
#     position: fixed;
#     top: 8px;
#     left: 24px;
#     width: calc(100% - 48px);
#     box-shadow: 0 1px 4px #00000010;
#   }
#   .ul-naviBarImg {
#     width: 138px;
#     margin-top: 8px;
#     margin-bottom: 8px;
#     margin-left: 16px;
#   }
#   .ul-naviBarA1,
#   .ul-naviBarA2,
#   .ul-naviBarA3,
#   .ul-naviBarA4 {
#     width: 94px;
#     display: block;
#     font-size: 14px;
#     font-weight: 600;
#     line-height: 21px;
#     letter-spacing: 0.02em;
#     text-align: center;
#     color: #262626;
#   }
#   .ul-naviBarA1 {
#     margin-left: auto;
#   }
#   .ul-naviBarA2,
#   .ul-naviBarA3,
#   .ul-naviBarA4 {
#     margin-left: 24px;
#   }
#   .ul-naviBarA1:hover,
#   .ul-naviBarA2:hover,
#   .ul-naviBarA3:hover,
#   .ul-naviBarA4:hover {
#     color: var(--tech0-color6);
#   }
#
#   .ul-naviBarA5 {
#     margin-right: 27px;
#     margin-left: 169px;
#     text-align: center;
#     font-size: 19px;
#     width: 40px;
#     max-width: 40px;
#     line-height: 41px;
#     height: 40px;
#     border-radius: 100%;
#     background-color: #f3f3f3;
#     caret-color: transparent;
#   }
#   .ul-naviBarA5:hover {
#     background-color: var(--tech0-color6);
#     cursor: pointer;
#   }
#
#   .open {
#     width: 100%;
#     cursor: pointer;
#   }
#   #pop-up {
#     display: none;
#   }
#   .overlay {
#     display: none;
#   }
#   #pop-up:checked + .overlay {
#     display: block;
#     z-index: 9999;
#     background-color: #00000070;
#     position: fixed;
#     width: 100%;
#     height: 100vh;
#     top: 0;
#     left: 0;
#   }
#
#   .window {
#     width: 90vw;
#     max-width: 590px;
#     height: 640px;
#     background-color: #f3f3f3;
#     position: fixed;
#     top: 8px;
#     right: 0px;
#   }
#   .window:hover {
#     cursor: default;
#   }
#
#   .close {
#     cursor: pointer;
#     position: absolute;
#     top: 56px;
#     right: 51px;
#     font-size: 20px;
#     color: #fff;
#     background-color: #737374;
#     width: 40px;
#     max-width: 40px;
#     height: 40px;
#     line-height: 41px;
#     border-radius: 100%;
#   }
#   .close-w {
#     cursor: default !important;
#     width: 100%;
#     height: 100%;
#   }
#   .close-w span {
#     display: none;
#   }
#
#   .ulul-naviBarImg {
#     margin-top: 48px;
#     margin-left: 48px;
#     width: 144px;
#   }
#   .ulul-naviBarA1 a,
#   .ulul-naviBarA2 a,
#   .ulul-naviBarA3 a,
#   .ulul-naviBarA4 a {
#     display: block;
#     text-align: left;
#     margin-left: 60px;
#     font-size: 16px;
#     font-weight: 600;
#     line-height: 24px;
#     letter-spacing: 0.02em;
#     text-align: left;
#     padding-top: 12px;
#     padding-bottom: 32px;
#     width: 388px;
#     border-bottom: 1px solid #bbb;
#   }
#   .ulul-naviBarA1 {
#     margin-top: 28px;
#   }
#   .ulul-naviBarA2,
#   .ulul-naviBarA3,
#   .ulul-naviBarA4 {
#     margin-top: 32px;
#   }
#   .ulul-icon a {
#     position: relative;
#   }
#   .ulul-icon a::before {
#     content: "\f105";
#     font-weight: 900;
#     font-family: "Font Awesome 6 Free";
#     position: absolute;
#     color: var(--tech0-color6);
#     top: 12px;
#     right: 24px;
#     transform: scale(1.5, 1);
#   }
#   .ulul2-naviBar {
#     text-align: center;
#
#     font-size: 12px;
#     font-weight: 300;
#     line-height: 18px;
#     letter-spacing: 0.02em;
#     text-align: center;
#   }
#   .ulul2-naviBar a {
#     display: block;
#     width: 144px;
#     margin-top: 92px;
#     color: #737374;
#   }
#   .ulul2-naviBarA1 {
#     margin-left: 49px;
#   }
#   .ulul2-naviBarA2 {
#     margin-left: 25px;
#   }
# }
# @media screen and (max-width: 959px) {
#   .ul-naviBar {
#     z-index: 10;
#     background-color: #fff;
#     align-items: center;
#     border-radius: 16px;
#     position: fixed;
#     top: 8px;
#     left: 16px;
#     width: calc(100% - 32px);
#     box-shadow: 0 1px 4px #00000010;
#   }
#   .ul-naviBarImg {
#     width: 100px;
#     margin-top: 5px;
#     margin-bottom: 5px;
#     margin-left: 8px;
#   }
#   .ul-naviBarA1,
#   .ul-naviBarA2,
#   .ul-naviBarA3,
#   .ul-naviBarA4 {
#     display: none;
#   }
#
#   .ul-naviBarA5 {
#     margin-right: 8px;
#     margin-left: auto;
#     text-align: center;
#     font-size: 15px;
#     width: 32px;
#     max-width: 32px;
#     line-height: 33px;
#     height: 32px;
#     border-radius: 100%;
#     background-color: #f3f3f3;
#     caret-color: transparent;
#   }
#   .ul-naviBarA5:hover {
#     background-color: var(--tech0-color6);
#     cursor: pointer;
#   }
#
#   .open {
#     width: 100%;
#     cursor: pointer;
#   }
#   #pop-up {
#     display: none;
#   }
#   .overlay {
#     display: none;
#   }
#   #pop-up:checked + .overlay {
#     display: block;
#     z-index: 9999;
#     background-color: #00000070;
#     position: fixed;
#     width: 100%;
#     height: 100vh;
#     top: 0;
#     left: 0;
#   }
#
#   .window {
#     width: 90vw;
#     max-width: 320px;
#     height: 600px;
#     background-color: #f3f3f3;
#     position: fixed;
#     top: 8px;
#     right: 0px;
#   }
#   .window:hover {
#     cursor: default;
#   }
#
#   .close {
#     cursor: pointer;
#     position: absolute;
#     top: 28px;
#     right: 24px;
#     font-size: 15px;
#     color: #fff;
#     background-color: #737374;
#     width: 32px;
#     max-width: 32px;
#     height: 32px;
#     line-height: 33px;
#     border-radius: 100%;
#   }
#   .close-w {
#     cursor: default !important;
#     width: 100%;
#     height: 100%;
#   }
#   .close-w span {
#     display: none;
#   }
#
#   .ulul-naviBarImg {
#     margin-top: 16px;
#     margin-left: 16px;
#     width: 144px;
#   }
#   .ulul-naviBarA1 a,
#   .ulul-naviBarA2 a,
#   .ulul-naviBarA3 a,
#   .ulul-naviBarA4 a {
#     display: block;
#     text-align: left;
#     margin-left: 32px;
#     font-size: 16px;
#     font-weight: 600;
#     line-height: 24px;
#     letter-spacing: 0.02em;
#     text-align: left;
#     padding-bottom: 32px;
#     width: 256px;
#     border-bottom: 1px solid #bbb;
#   }
#   .ulul-naviBarA1 {
#     margin-top: 72px;
#   }
#   .ulul-naviBarA2,
#   .ulul-naviBarA3,
#   .ulul-naviBarA4 {
#     margin-top: 32px;
#   }
#   .ulul-icon a {
#     position: relative;
#   }
#   .ulul-icon a::before {
#     content: "\f105";
#     font-weight: 900;
#     font-family: "Font Awesome 6 Free";
#     position: absolute;
#     color: var(--tech0-color6);
#     top: 12px;
#     right: 16px;
#     transform: scale(1.5, 1);
#   }
#   .ulul2-naviBar {
#     text-align: center;
#
#     font-size: 11px;
#     font-weight: 300;
#     line-height: 16.5px;
#     letter-spacing: 0.02em;
#     text-align: center;
#   }
#   .ulul2-naviBar a {
#     display: block;
#     width: 120px;
#     margin-top: 95px;
#     color: #737374;
#   }
#   .ulul2-naviBarA1 {
#     margin-left: 32px;
#   }
#   .ulul2-naviBarA2 {
#     margin-left: 16px;
#   }
# }
#
# .faq-div1 {
# 	padding-top: 10px;
# 	margin-top:-10px;
# }
#
# .olol li {
# 	list-style-type: none;
# 	counter-increment: cnt;
# 	position:relative;
# }
#
# .olol li::before {
# 	content: "(" counter(cnt) ") ";
# 	position:absolute;
# 	top:0;
# 	left:-1.5em;
# }		</style>
# 		</head>
#
# <body class="home page-template-default page page-id-505 no-sidebar">
# 	<main id="primary" class="site-main">
#
# 		<article id="post-505" class="post-505 page type-page status-publish hentry wpautop">
#
# 	<div class="entry-content">
#
# <style>
# footer a {
# 	color:inherit !important;
# }
# footer a:hover {
# 	color:inherit !important;
# }
# footer {
#   margin-top:50px  !important;
# }
# body {
#   padding-bottom:0 !important;
# }
# .logo {
#   max-width: 180px !important;
# }
# *,
# *::before,
# *::after {
#   margin: 0;
#   padding: 0;
#   box-sizing: border-box;
# }
#
# :where([hidden]:not([hidden="until-found"])) {
#   display: none !important;
# }
#
# :where(html) {
#   -webkit-text-size-adjust: none;
#   color-scheme: dark light;
# }
#
# @supports not (min-block-size: 100dvb) {
#   :where(html) {
#     block-size: 100%;
#   }
# }
# @media (prefers-reduced-motion: no-preference) {
#   :where(html:focus-within) {
#     scroll-behavior: smooth;
#   }
# }
# :where(body) {
#   line-height: 1.5;
#   font-family: system-ui, sans-serif;
#   -webkit-font-smoothing: antialiased;
# }
#
# :where(input, button, textarea, select) {
#   font: inherit;
#   color: inherit;
# }
#
# :where(textarea) {
#   resize: vertical;
#   resize: block;
# }
#
# :where(button, label, select, summary, [role="button"], [role="option"]) {
#   cursor: pointer;
# }
#
# :where(:disabled) {
#   cursor: not-allowed;
# }
#
# :where(label:has(> input:disabled), label:has(+ input:disabled)) {
#   cursor: not-allowed;
# }
#
# :where(button) {
#   border-style: solid;
# }
#
# :where(a) {
#   text-underline-offset: 0.2ex;
# }
#
# :where(ul, ol) {
#   list-style: none;
# }
#
# :where(img, svg, video, canvas, audio, iframe, embed, object) {
#   display: block;
# }
#
# :where(img, picture, svg) {
#   max-inline-size: 100%;
#   block-size: auto;
# }
#
# :where(p, h1, h2, h3, h4, h5, h6) {
#   overflow-wrap: break-word;
# }
#
# :where(h1, h2, h3) {
#   line-height: calc(1em + 0.5rem);
# }
#
# :where(hr) {
#   border: none;
#   border-block-start: 1px solid;
#   color: inherit;
#   block-size: 0;
#   overflow: visible;
# }
#
# :where(:focus-visible) {
#   outline: 2px solid var(--focus-color, Highlight);
#   outline-offset: 2px;
# }
#
# :where(
#     .visually-hidden:not(:focus, :active, :focus-within, .not-visually-hidden)
#   ) {
#   clip-path: inset(50%) !important;
#   height: 1px !important;
#   width: 1px !important;
#   overflow: hidden !important;
#   position: absolute !important;
#   white-space: nowrap !important;
#   border: 0 !important;
# }
#
# .for-sp {
#   display: none !important;
# }
# @media screen and (max-width: 720px) {
#   .for-sp {
#     display: inherit !important;
#   }
# }
#
# .for-pc {
#   display: inherit !important;
# }
# @media screen and (max-width: 720px) {
#   .for-pc {
#     display: none !important;
#   }
# }
#
# .fw-normal {
#   font-weight: normal;
# }
#
# .width-full {
#   width: 100%;
#   max-width: none;
#   margin-left: 0;
#   margin-right: 0;
#   padding-left: 0;
#   padding-right: 0;
# }
# @media screen and (max-width: 720px) {
#   .width-full.-pc {
#     width: 90%;
#     padding: 0;
#   }
# }
#
# small,
# .txt-small {
#   font-size: 0.7em;
# }
#
# .fx-col-3 {
#   display: flex;
#   justify-content: space-between;
#   align-items: start;
#   flex-wrap: wrap;
# }
# .fx-col-3 > * {
#   width: 33.25%;
# }
# .fx-col-3.space {
#   gap: 40px;
# }
# .fx-col-3.space > * {
#   width: calc(30% - 10px);
# }
# .fx-col-3:after {
#   content: "";
#   display: block;
#   width: calc(33% - 20px);
# }
# @media screen and (max-width: 720px) {
#   .fx-col-3 {
#     flex-direction: column;
#   }
#   .fx-col-3.space > * {
#     width: 100%;
#   }
# }
# .fx-col-2 {
#   display: flex !important;
#   justify-content: space-between;
#   align-items: start;
#   flex-wrap: wrap;
# }
# .fx-col-2 > * {
#   width: 50%;
# }
# .fx-col-2.space {
#   gap: 48px;
#   margin: 20px 0 20px 0;
# }
# .fx-col-2.space > * {
#   width: calc(50% - 48px);
# }
# @media screen and (max-width: 720px) {
#   .fx-col-2.space > * {
#     width: 100%;
#   }
# }
# .fx-col-2:after {
#   content: "";
#   display: block;
#   width: calc(50% - 20px);
# }
# @media screen and (max-width: 720px) {
#   .fx-col-2 {
#     flex-direction: column;
#   }
# }
# @media screen and (max-width: 720px) {
#   .fx-col-2.swiper-wrapper {
#     flex-direction: row;
#     flex-wrap: nowrap;
#     gap: 0 !important;
#     margin-top: 0;
#   }
# }
#
# [data-aos="fade-up-bit"] {
#   transform: translateY(10%);
#   opacity: 0;
#   transition-property: transform, opacity;
# }
# [data-aos="fade-up-bit"].aos-animate {
#   transform: translateY(0);
#   opacity: 1;
# }
#
# [data-aos="fade-left-bit"] {
#   transform: translateX(10%);
#   opacity: 0;
#   transition-property: transform, opacity;
# }
# [data-aos="fade-left-bit"].aos-animate {
#   transform: translateX(0);
#   opacity: 1;
# }
#
# html {
#   scroll-behavior: smooth;
# }
#
# body {
#   font-family: "Noto Sans JP", sans-serif;
#   background-color: #fff;
#   color: #2c2a25;
#   padding-top: 72px;
#   font-size: 15px;
# }
# @media screen and (max-width: 720px) {
#   body {
#     padding-top: 56px;
#   }
# }
#
# :where(img, svg) {
#   display: inline-block;
# }
#
# main a {
#   color: #127fcd;
#   display: inline-block;
# }
# main p {
#   margin: 1.5em 0;
#   line-height: 1.8em;
# }
# main .content {
#   position: relative;
#   max-width: 1100px;
#   margin-left: auto;
#   margin-right: auto;
#   padding: 0 min(30px, 3vw);
#   padding: 0 50px;
# }
# @media screen and (max-width: 720px) {
#   main .content {
#     padding: 0 25px;
#   }
# }
# main h3 {
#   line-height: 1.7em;
#   font-size: 20px;
#   border-left: 8px solid #127fcd;
#   padding-left: 1em;
#   margin: 90px 0 20px 0;
# }
# main details summary {
#   color: #2c2a25;
#   font-weight: bold;
#   margin: 30px 0;
#   padding: 10px 0;
#   outline: none;
#   display: flex;
#   align-items: center;
# }
# main details summary::-webkit-details-marker {
#   display: none;
# }
# main details summary:before {
#   display: inline-block;
#   margin-right: 10px;
# }
# @media screen and (max-width: 720px) {
#   main details summary {
#     margin: 20px 0;
#   }
# }
# main details.more summary {
#   justify-content: center;
#   color: #127fcd;
# }
# main details.more summary:before {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_plus.svg);
# }
# main details[open] *:last-child {
#   animation: fadeDown 0.5s ease;
#   animation-fill-mode: both;
# }
#
# @keyframes fadeIn {
#   0% {
#     opacity: 0;
#   }
#   100% {
#     opacity: 1;
#   }
# }
# @keyframes fadeDown {
#   0% {
#     opacity: 0;
#     transform: translateY(-10px);
#   }
#   100% {
#     opacity: 1;
#     transform: none;
#   }
# }
# @keyframes slideLeft {
#   0% {
#     opacity: 0;
#     transform: translateX(20px);
#   }
#   100% {
#     opacity: 1;
#     transform: none;
#   }
# }
# .btn {
#   display: inline-block;
#   border: 1px solid #324451;
#   border-radius: 48px;
#   font-size: 13px;
#   font-weight: bold;
#   padding: 0px 24px;
#   height: 48px;
#   line-height: 48px;
#   color: inherit;
#   text-decoration: none;
#   transition: all 0.2s ease;
# }
# .btn:hover {
#   border-color: #7da3c0;
# }
# .btn.invert {
#   background: #324451;
#   color: white;
# }
# .btn.borderless {
#   border: none;
#   color: #127fcd;
# }
#
# .annotation {
#   margin: 2em 0;
# }
# .annotation li {
#   padding: 0.2em 0;
# }
#
# .panels {
#   display: flex;
#   flex-wrap: wrap;
#   justify-content: space-between;
# }
# @media screen and (max-width: 720px) {
#   .panels.swiper-wrapper {
#     flex-direction: row;
#     flex-wrap: nowrap;
#   }
# }
# @media screen and (max-width: 900px) {
#   .panels:not(.swiper-wrapper) {
#     flex-direction: row;
#   }
#   .panels:not(.swiper-wrapper) .panel {
#     width: 100%;
#     max-width: none;
#   }
# }
# .panels .panel {
#   background: #f5f6fa;
#   border-radius: 24px;
#   margin-bottom: 28px;
#   margin-top: 28px;
#   max-width: 472px;
#   width: 47.2%;
# }
# .panels .panel.swiper-slide {
#   margin-bottom: 40px;
# }
# @media screen and (max-width: 720px) {
#   .panels .panel {
#     max-width: none;
#   }
# }
# .panels .panel .head {
#   display: flex;
#   justify-content: space-between;
#   flex-wrap: wrap;
#   align-items: start;
#   background-color: #eee;
#   border-radius: 24px 24px 0 0;
# }
# .panels .panel .head h3 {
#   font-size: 24px;
#   font-size: clamp(1rem, 0.795rem + 1.03vw, 1.5rem);
#   margin: 0;
#   line-height: 1.4em;
#   flex: 1;
# }
# .panels .panel .head h3 span {
#   font-size: 20px;
#   display: block;
#   opacity: 0.6;
#   margin-bottom: 4px;
# }
# .panels .panel .head p {
#   width: 100%;
#   margin-bottom: 0;
# }
# .panels .panel .head .span {
#   border: 1px solid rgba(255, 255, 255, 0.4);
#   width: 72px;
#   aspect-ratio: 1/1;
#   border-radius: 50%;
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   flex-direction: column;
#   font-size: 12px;
#   line-height: 1.3;
# }
# .panels .panel .head .span strong {
#   font-size: 18px;
# }
# .panels .panel > div {
#   padding: 25px 7.63% 39px 7.63%;
# }
# .panels .panel h3 {
#   font-size: 16px;
#   padding: 0;
#   border: none;
#   margin: 0.5em 0 1em 0;
# }
# .panels .panel h4 {
#   font-size: 12px;
#   font-weight: normal;
# }
# .panels .panel ul:not(.tags) {
#   font-size: 12px;
#   display: flex;
#   flex-wrap: wrap;
#   border-bottom: 1px solid #999;
#   margin-top: 20px;
#   padding-bottom: 20px;
#   margin-bottom: 20px;
# }
# .panels .panel ul:not(.tags) li {
#   padding: 2px 0;
#   width: 50%;
#   min-width: 130px;
# }
# .panels .panel ul:not(.tags) li:before {
#   content: "\26AB︎";
#   display: inline-block;
#   margin-right: 5px;
# }
# .panels .panel .date {
#   font-size: 13px;
# }
# .panels .panel .btnArea {
#   margin: 40px 0 0 0;
# }
# .panels .panel.light-blue {
#   background-color: #f1f9f9;
# }
# .panels .panel.light-blue .head {
#   background-color: #a4c7d6;
#   color: white;
# }
# .panels .panel.light-blue h4 {
#   color: #a4c7d6;
# }
# .panels .panel.light-blue ul:not(.tags) {
#   border-color: #a4c7d6;
# }
# .panels .panel.light-blue ul:not(.tags) li:before {
#   color: #a4c7d6;
# }
# .panels .panel.light-green {
#   background-color: #f1f9f9;
# }
# .panels .panel.light-green .head {
#   background-color: #a4d6d4;
#   color: white;
# }
# .panels .panel.light-green h4 {
#   color: #a4d6d4;
# }
# .panels .panel.light-green ul:not(.tags) {
#   border-color: #a4d6d4;
# }
# .panels .panel.light-green ul:not(.tags) li:before {
#   color: #a4d6d4;
# }
#
# .index_header {
#   display: flex;
#   position: fixed;
#   top: 0;
#   left: 0;
#   right: 0;
#   z-index: 100;
#   justify-content: space-between;
#   align-items: center;
#   background-color: #fff;
#   height: 72px;
#   filter: drop-shadow(0px 4px 4px rgba(0, 0, 0, 0.25));
# }
# .index_header button.btn_menu {
#   background: transparent;
#   border: none;
#   outline: none;
#   margin: 0 2vw;
#   width: 50px;
# }
# .index_header button.btn_menu:before {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_menu_open.svg);
#   display: inline-block;
# }
# .index_header > *:last-child {
#   display: flex;
#   vertical-align: middle;
# }
# .index_header nav {
#   flex: 1;
# }
# .index_header nav ul {
#   display: flex;
#   text-align: center;
#   justify-content: center;
#   gap: 2vw;
#   font-weight: bold;
# }
# .index_header nav ul a {
#   color: #2c2a25;
#   text-decoration: none;
# }
# .index_header nav ul a:hover {
#   transition: all 0.3s;
#   color: #127fcd;
# }
# .index_header nav ul a:hover span {
#   border-top: 1px solid #127fcd;
# }
# .index_header nav ul span {
#   display: block;
#   font-weight: normal;
#   font-size: 0.5rem;
#   opacity: 0.5;
#   border-top: 1px solid transparent;
# }
# @media screen and (max-width: 1180px) {
#   .index_header nav {
#     display: none;
#   }
# }
# .index_header a {
#   display: inline-block;
# }
# @media screen and (max-width: 720px) {
#   .index_header {
#     height: 56px;
#   }
#   .index_header .logo {
#     width: 140px;
#   }
# }
#
# body.menu-open {
#   overflow-y: hidden;
# }
# body.menu-open nav.all {
#   display: flex;
#   align-items: center;
#   animation: fadeIn 0.5s;
# }
# body.menu-open nav.all li {
#   animation: slideLeft 0.3s ease-out backwards;
# }
# body.menu-open nav.all li:nth-child(2) {
#   animation-delay: 0.1s;
# }
# body.menu-open nav.all li:nth-child(3) {
#   animation-delay: 0.15s;
# }
# body.menu-open nav.all li:nth-child(4) {
#   animation-delay: 0.2s;
# }
# body.menu-open nav.all li:nth-child(5) {
#   animation-delay: 0.25s;
# }
# body.menu-open nav.all li:nth-child(6) {
#   animation-delay: 0.3s;
# }
# body.menu-open nav.all li:nth-child(7) {
#   animation-delay: 0.35s;
# }
# body.menu-open nav.all li:nth-child(8) {
#   animation-delay: 0.4s;
# }
# body.menu-open nav.all li:nth-child(9) {
#   animation-delay: 0.45s;
# }
# body.menu-open nav.all li:nth-child(10) {
#   animation-delay: 0.5s;
# }
# body.menu-open nav.all li:nth-child(11) {
#   animation-delay: 0.55s;
# }
# body.menu-open nav.all li:nth-child(12) {
#   animation-delay: 0.6s;
# }
# body.menu-open nav.all li:nth-child(13) {
#   animation-delay: 0.65s;
# }
# body.menu-open nav.all li:nth-child(14) {
#   animation-delay: 0.7s;
# }
# body.menu-open nav.all li:nth-child(15) {
#   animation-delay: 0.75s;
# }
# body.menu-open nav.all li:nth-child(16) {
#   animation-delay: 0.8s;
# }
# body.menu-open nav.all li:nth-child(17) {
#   animation-delay: 0.85s;
# }
# body.menu-open nav.all li:nth-child(18) {
#   animation-delay: 0.9s;
# }
# body.menu-open nav.all li:nth-child(19) {
#   animation-delay: 0.95s;
# }
# body.menu-open nav.all li:nth-child(20) {
#   animation-delay: 1s;
# }
# body.menu-open .index_header .btn_menu:before {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_menu_close.svg);
# }
# body.menu-open .index_header nav {
#   display: none;
# }
#
# nav.all {
#   display: none;
#   flex-direction: column;
#   position: fixed;
#   z-index: 101;
#   top: 72px;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   background: rgba(248, 248, 248, 0.97);
#   overflow-y: auto;
#   overscroll-behavior: none;
# }
# @media screen and (max-width: 720px) {
#   nav.all {
#     align-items: start;
#     top: 56px;
#   }
# }
# nav.all > ul {
#   display: flex;
#   flex-wrap: wrap;
#   justify-content: center;
#   max-width: 1200px;
#   margin: 20px 5dvw;
# }
# nav.all > ul a {
#   color: #2c2a25;
# }
# nav.all > ul:nth-of-type(1) {
#   gap: 40px;
#   margin-top: 100px;
#   margin-bottom: 100px;
# }
# @media screen and (max-width: 720px) {
#   nav.all > ul:nth-of-type(1) {
#     width: 75dvw;
#     max-width: 330px;
#     margin: 4dvh 0;
#     gap: 0;
#   }
# }
# nav.all > ul:nth-of-type(1) li {
#   max-width: 290px;
#   width: 40%;
# }
# @media screen and (min-width: 1025px) {
#   nav.all > ul:nth-of-type(1) li {
#     width: 30%;
#   }
# }
# @media screen and (max-width: 720px) {
#   nav.all > ul:nth-of-type(1) li {
#     width: 100%;
#     max-width: 330px;
#   }
# }
# nav.all > ul:nth-of-type(1) a {
#   display: inline-block;
#   text-decoration: none;
#   padding: 18px 0 18px 6px;
#   color: inherit;
#   display: flex;
#   align-items: center;
#   position: relative;
#   border-bottom: 1px solid #d9d9d9;
#   font-size: 12px;
# }
# nav.all > ul:nth-of-type(1) a:hover {
#   transition: all 0.3s;
#   color: #127fcd;
#   border-color: #127fcd;
# }
# nav.all > ul:nth-of-type(1) a strong {
#   font-size: 15px;
#   width: 35%;
# }
# nav.all > ul:nth-of-type(1) a:after {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_arrow-r.svg);
#   position: absolute;
#   right: 0;
# }
# @media screen and (max-width: 720px) {
#   nav.all > ul:nth-of-type(1) a {
#     padding: 2.2em 0 2.2em 6px;
#   }
# }
#
# nav .other {
#   display: flex;
#   gap: 30px;
#   font-size: 10px;
#   justify-content: center;
# }
# @media screen and (max-width: 720px) {
#   nav .other {
#     flex-direction: column;
#     gap: 10px;
#   }
# }
# nav .other a {
#   text-decoration: none;
# }
# nav .other a:hover {
#   text-decoration: underline;
# }
# nav .sns {
#   display: flex;
#   justify-content: center;
#   gap: 35px;
# }
#
# :target::before {
#   content: "";
#   display: block;
#   height: 72px; /* ずらしたい高さ */
#   margin-top: -72px; /* heightに対するネガティブマージン */
#   visibility: hidden;
# }
# @media screen and (max-width: 720px) {
#   :target::before {
#     height: 56px; /* ずらしたい高さ */
#     margin-top: -56px; /* heightに対するネガティブマージン */
#   }
# }
#
# main {
#   overflow-x: hidden;
# }
# main section {
#   margin: 0 auto 150px auto;
# }
# @media screen and (max-width: 720px) {
#   main section {
#     margin-bottom: 130px;
#   }
# }
# main h2 {
#   font-size: 32px;
#   line-height: 1.7em;
#   margin-bottom: 60px;
# }
# main h2:before {
#   display: block;
#   content: attr(data-en-title);
#   font-size: 16px;
#   font-weight: normal;
#   color: #127fcd;
# }
# main h2 + p {
#   margin-top: -30px;
#   margin-bottom: 50px;
# }
# @media screen and (max-width: 720px) {
#   main h2 {
#     font-size: 24px;
#     margin-bottom: 40px;
#   }
#   main h2 + p {
#     margin-top: 0;
#   }
# }
#
# #mv {
#   height: calc(100vh - 72px);
#   position: relative;
#   display: flex;
#   flex-direction: column;
#   justify-content: space-between;
# }
# #mv:before {
#   display: block;
#   margin: auto;
#   position: absolute;
#   left: 0;
#   right: 0;
#   top: 0;
#   height: 200px;
#   width: 1200px;
#   max-width: 1300px;
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting01.jpg);
#   transform: translateX(-200px);
#   background-repeat: no-repeat;
#   background-size: auto 100%;
#   margin: auto;
# }
# @media screen and (max-width: 720px) {
#   #mv {
#     height: calc(100vh - 56px);
#     background-size: contain;
#   }
# }
# #mv .badge {
#   padding: 3vh 0 3vh 20px;
#   display: flex;
#   align-items: center;
#   gap: 15px;
#   width: 100%;
#   margin: auto;
#   max-width: 1100px;
# }
# #mv .badge img {
#   height: 100%;
#   max-height: 160px;
#   display: inline-block;
# }
# @media screen and (max-width: 720px) {
#   #mv .badge img {
#     height: 120px;
#   }
# }
# #mv .copy {
#   margin-right: auto;
#   margin-left: auto;
#   width: 100%;
#   max-width: 1100px;
# }
# #mv .copy h1 {
#   background-color: #92bed0;
#   color: white;
#   padding: 3.5vh 80px 3.5vh 80px;
#   white-space: nowrap;
#   font-size: 48px;
#   letter-spacing: 1px;
#   font-size: clamp(1.75rem, 1rem + 3vw, 3rem);
#   margin-right: 25%;
# }
# #mv .copy strong {
#   display: inline-block;
#   line-height: 1em;
#   background: #127fcd;
#   color: white;
#   padding: 12px;
#   margin: 0 8px;
# }
# @media screen and (max-width: 720px) {
#   #mv .copy {
#     padding-left: 0;
#     margin-right: 0;
#     font-size: clamp(1.75rem, 1.0159rem + 2vh, 3rem);
#     transition: margin 0.3s ease-out;
#   }
#   #mv .copy h1 {
#     margin-right: 0;
#     padding-left: 6vw;
#   }
#   #mv .copy strong {
#     padding: 6px;
#   }
# }
# #mv .contact {
#   display: grid;
#   place-content: center;
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting02.jpg);
#   background-repeat: no-repeat;
#   background-position: 90px bottom;
#   width: 100%;
#   padding-left: 80px;
#   max-width: 1100px;
#   margin: auto;
#   flex: 1;
#   justify-content: left;
# }
# #mv .contact a {
#   position: relative;
#   z-index: 10;
# }
# @media screen and (max-width: 720px) {
#   #mv .contact {
#     margin-left: 0;
#     width: auto;
#     place-content: flex-end flex-start;
#     background-size: 75%;
#     background-position: left bottom;
#     padding-left: 0;
#   }
#   #mv .contact a {
#     width: 95%;
#     margin: 0 auto 20px auto;
#   }
# }
# #mv .img-person {
#   position: absolute;
#   content: "";
#   display: inline-block;
#   max-height: 850px;
#   height: 100%;
#   width: 100%;
#   bottom: 0;
#   left: 48%;
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_mv.png);
#   background-repeat: no-repeat;
#   background-position: left bottom;
#   background-size: contain;
#   pointer-events: none;
# }
# @media screen and (max-width: 720px) {
#   #mv .img-person {
#     aspect-ratio: 1/1;
#     height: 94%;
#     width: auto;
#     background-position: right bottom;
#     left: auto;
#     right: -30vh;
#     max-height: 750px;
#   }
# }
#
# #about_us {
#   margin: auto;
#   position: relative;
# }
# #about_us h2:before {
#   position: absolute;
#   top: 0;
#   right: 110%;
#   white-space: nowrap;
# }
# @media screen and (max-width: 720px) {
#   #about_us h2:before {
#     position: initial;
#   }
# }
# #about_us h3 {
#   padding-left: 0;
#   border: none;
#   font-size: 24px;
# }
# #about_us .content:first-of-type {
#   font-size: 16px;
# }
# #about_us > div {
#   padding-left: 24vw;
#   margin-bottom: 150px;
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting03.jpg);
#   background-repeat: no-repeat;
# }
# @media screen and (max-width: 720px) {
#   #about_us > div {
#     padding-left: 5%;
#     margin-bottom: 50px;
#     background-position: 100% -4%;
#     background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting07.jpg);
#   }
#   #about_us > div .fx-col-3 {
#     flex-direction: row;
#   }
# }
# #about_us > div:first-child {
#   background-image: none;
# }
# #about_us > div.evaluation .fx-col-3 > * {
#   min-height: 136px;
#   background-repeat: no-repeat;
#   background-position: center;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
#   color: #127fcd;
#   font-size: 13px;
#   letter-spacing: 2px;
# }
# @media screen and (max-width: 720px) {
#   #about_us > div.evaluation .fx-col-3 > * {
#     letter-spacing: -0.1em;
#   }
# }
# #about_us > div.evaluation .fx-col-3 > *:nth-child(1) {
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting04.jpg);
# }
# @media screen and (max-width: 900px) {
#   #about_us > div.evaluation .fx-col-3 > *:nth-child(1) {
#     width: 100%;
#   }
# }
# #about_us > div.evaluation .fx-col-3 > *:nth-child(2) {
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting05.jpg);
# }
# @media screen and (max-width: 900px) {
#   #about_us > div.evaluation .fx-col-3 > *:nth-child(2) {
#     width: 50%;
#   }
# }
# #about_us > div.evaluation .fx-col-3 > *:nth-child(3) {
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_painting06.jpg);
# }
# @media screen and (max-width: 900px) {
#   #about_us > div.evaluation .fx-col-3 > *:nth-child(3) {
#     width: 50%;
#   }
# }
# #about_us > div.evaluation .fx-col-3 > * strong {
#   font-size: 56px;
# }
# #about_us > div.evaluation .fx-col-3 > * small {
#   font-size: 0.25em;
# }
# #about_us > div.achievement .btnArea {
#   margin-top: 0;
# }
# #about_us h3 {
#   color: #127fcd;
#   padding: 50px 0 50px 0;
#   text-align: center;
# }
# @media screen and (max-width: 720px) {
#   #about_us h3 {
#     font-size: 15px;
#   }
# }
# #about_us .fx-col-3 {
#   align-items: center;
# }
# #about_us .fx-col-3 > * {
#   text-align: center;
# }
#
# #why .fx-col-2 {
#   margin-top: 50px;
# }
# #why .fx-col-2 > * {
#   text-align: center;
# }
# #why h4 {
#   font-size: 16px;
# }
# #why img {
#   margin-top: 30px;
# }
#
# #reason .no {
#   border: 1px solid #127fcd;
#   border-radius: 50%;
#   position: relative;
#   font-size: 24px;
#   width: 56px;
#   aspect-ratio: 1/1;
#   color: #127fcd;
#   font-weight: bold;
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   text-align: center;
#   margin: 150px auto 0 auto;
# }
# #reason .no:before {
#   content: "理由";
#   font-size: 14px;
#   position: absolute;
#   bottom: 120%;
#   line-height: 1;
#   left: 0;
#   right: 0;
# }
# #reason .no + h3 {
#   margin-top: 20px;
# }
# #reason h3 {
#   font-size: 32px;
#   text-align: center;
#   border: none;
#   margin-bottom: 56px;
#   padding-left: 0;
# }
# @media screen and (max-width: 720px) {
#   #reason h3 {
#     font-size: 24px;
#   }
# }
# #reason .swiper-wrapper {
#   flex-direction: column;
# }
# @media screen and (max-width: 720px) {
#   #reason .swiper-wrapper {
#     flex-direction: row;
#   }
# }
# #reason .fx-col-2 {
#   gap: 48px;
#   margin: 20px 0 20px 0;
# }
# #reason .fx-col-2 > * {
#   width: calc(50% - 48px);
# }
# @media screen and (max-width: 720px) {
#   #reason .fx-col-2 > * {
#     width: 100%;
#   }
# }
# @media screen and (max-width: 720px) {
#   #reason .fx-col-2 > * {
#     width: 100%;
#   }
# }
# #reason .fx-col-2 h4 {
#   font-size: 20px;
# }
# @media screen and (max-width: 720px) {
#   #reason .fx-col-2 h4 {
#     font-size: 17px;
#   }
# }
# #reason figure {
#   max-width: 456px;
# }
# @media screen and (max-width: 720px) {
#   #reason figure {
#     max-width: none;
#   }
# }
# #reason figcaption h4 {
#   font-size: 20px;
#   display: flex;
#   align-items: center;
#   margin: 1em 0;
# }
# @media screen and (max-width: 720px) {
#   #reason figcaption h4 {
#     align-items: start;
#     font-size: 17px;
#   }
# }
# #reason figcaption span {
#   font-weight: normal;
#   display: inline-block;
#   aspect-ratio: 1/1;
#   font-size: 17px;
#   height: 36px;
#   line-height: 36px;
#   text-align: center;
#   margin: 0 8px;
#   border: 1px solid #127fcd;
#   color: #127fcd;
#   border-radius: 50%;
# }
# #reason .more .fx-col-2 > * {
#   max-width: 456px;
# }
#
# #voice .swiper-wrapper {
#   flex-direction: column;
#   align-items: center;
# }
# @media screen and (max-width: 720px) {
#   #voice .swiper-wrapper {
#     flex-direction: row;
#   }
# }
# #voice .voice {
#   margin-left: auto;
#   margin-right: auto;
#   margin-bottom: 50px;
#   max-width: 794px;
# }
# #voice .voice h3 {
#   border: none;
#   margin: 0;
# }
# @media screen and (max-width: 720px) {
#   #voice .voice h3 {
#     font-size: 16px;
#   }
# }
# #voice .voice > img {
#   width: 100px;
#   float: left;
#   margin-right: 5vw;
# }
# @media screen and (max-width: 720px) {
#   #voice .voice > img {
#     width: 80px;
#   }
# }
# #voice .voice > p {
#   overflow: hidden;
# }
# @media screen and (max-width: 720px) {
#   #voice .voice > p {
#     width: 100%;
#   }
# }
# #voice .interview {
#   margin-left: auto;
#   margin-right: auto;
#   justify-content: center;
# }
# #voice .interview *,
# #voice .interview:after {
#   width: 352px;
# }
# @media screen and (max-width: 720px) {
#   #voice .interview *,
#   #voice .interview:after {
#     width: 100%;
#   }
# }
#
# @media screen and (max-width: 720px) {
#   #program .panels .panel {
#     margin-left: -25px;
#     margin-right: -25px;
#     width: 100vw;
#     border-radius: 0;
#     max-width: none;
#   }
#   #program .panels .panel .head {
#     border-radius: 0;
#   }
# }
#
# @media screen and (max-width: 900px) {
#   #lecture .fx-col-3.space {
#     flex-direction: column;
#   }
# }
# @media screen and (max-width: 900px) {
#   #lecture .fx-col-3.space > * {
#     width: 500px;
#     margin-right: auto;
#     margin-left: auto;
#   }
# }
# @media screen and (max-width: 720px) {
#   #lecture .fx-col-3.space > * {
#     width: 100%;
#   }
# }
# #lecture .profile {
#   text-align: center;
# }
# #lecture .profile img {
#   max-width: 160px;
#   margin: auto;
# }
# #lecture .profile .name {
#   text-align: center;
#   display: block;
#   margin: 20px 0;
#   font-size: 10px;
# }
# #lecture .profile .name::first-line {
#   font-size: 16px;
# }
# #lecture .profile p {
#   text-align: left;
#   font-size: 13px;
# }
# @media screen and (max-width: 900px) {
#   #lecture .profile {
#     display: flex;
#     flex-wrap: wrap;
#     align-items: center;
#   }
#   #lecture .profile img {
#     width: 96px;
#     margin: 0;
#   }
#   #lecture .profile .name {
#     margin: 0;
#     text-align: left;
#     padding-left: 40px;
#   }
#   #lecture .profile p {
#     width: 100%;
#   }
# }
#
# #plan img.plan {
#   width: 720px;
#   margin: 0 auto 80px auto;
#   display: block;
# }
# #plan h3 {
#   border: none;
#   padding-left: 0;
#   font-size: 18px;
# }
# #plan ol {
#   display: flex;
#   flex-wrap: wrap;
#   margin: 20px 0;
#   counter-reset: count 0;
# }
# #plan ol li {
#   width: 33%;
#   padding: 10px;
# }
# #plan ol li:before {
#   content: counter(count);
#   counter-increment: count 1;
#   border-radius: 50%;
#   line-height: 0;
#   display: inline-flex;
#   align-items: center;
#   justify-content: center;
#   color: #127fcd;
#   margin-right: 10px;
#   width: 36px;
#   aspect-ratio: 1/1;
#   border: 1px solid #127fcd;
# }
# @media screen and (max-width: 720px) {
#   #plan ol li {
#     font-size: 12px;
#     width: 50%;
#     padding: 5px;
#   }
#   #plan ol li:before {
#     margin-right: 5px;
#     width: 16px;
#   }
# }
# #plan .other {
#   margin-top: 60px;
#   padding-top: 60px;
#   border-top: 1px solid #e6e6e6;
# }
# #plan .other h4 {
#   font-size: 11px;
# }
# #plan .other p {
#   font-size: 12px;
# }
#
# #apply a.zoom {
#   display: block;
#   margin: 20px 0;
# }
#
# #faq details {
#   border-bottom: 1px solid #e6e6e6;
#   font-size: 16px;
# }
# #faq details summary {
#   text-align: left;
#   display: flex;
#   align-items: center;
# }
# #faq details summary:before {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_faq-q.svg);
#   margin-right: 20px;
#   height: 17px;
# }
# #faq details p {
#   display: flex;
# }
# #faq details p:before {
#   margin-right: 20px;
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_faq-a.svg);
# }
#
# #news .date {
#   opacity: 0.7;
#   display: inline-block;
#   margin-right: 1.3em;
#   font-size: 16px;
# }
# #news dt {
#   padding-top: 20px;
# }
# #news dd {
#   padding: 15px 0 20px 0;
#   border-bottom: 1px solid #e6e6e6;
# }
# #news dd a {
#   color: inherit;
#   text-decoration: none;
#   display: flex;
#   justify-content: space-between;
# }
# #news dd a:hover {
#   text-decoration: underline;
# }
# #news dd a:after {
#   content: url(https://tech0-jp.com/wp-content/uploads/2023/06/ico_arrow-r.svg);
#   display: inline-block;
#   padding-left: 10px;
# }
#
# .contactArea {
#   display: flex;
#   flex-direction: column;
#   align-items: center;
#   justify-content: center;
#   background-image: url(https://tech0-jp.com/wp-content/uploads/2023/06/bg_contact.jpg);
#   background-repeat: no-repeat;
#   background-size: cover;
#   background-position: center;
#   min-height: 480px;
#   text-align: center;
#   color: white;
#   padding: 0 4vw;
# }
# .contactArea h2 {
#   font-size: 28px;
#   margin: 0;
# }
# .contactArea h2 + p {
#   margin-top: 0;
# }
# .contactArea h3 {
#   font-size: 28px;
#   margin: 0;
#   border: none;
#   padding: 0;
# }
# @media screen and (max-width: 720px) {
#   .contactArea {
#     font-size: 12px;
#     background-position: left;
#     min-height: 460px;
#   }
#   .contactArea h2,
#   .contactArea h3 {
#     font-size: 22px;
#   }
# }
#
# .tag,
# ul.tags li {
#   font-size: 10px;
#   padding: 0.6em 1.5em;
#   margin: 3px 2px;
#   line-height: 1;
#   color: #c6c6c6;
#   border: 1px solid #c6c6c6;
#   background-color: #fff;
#   vertical-align: bottom;
#   display: inline-block;
#   line-height: 1;
#   border-radius: 2px;
# }
# .tag.pale-teal,
# ul.tags li.pale-teal {
#   color: #8fc8ad;
#   border-color: #8fc8ad;
# }
# .tag.light-grey-blue,
# ...
#                 を利用したクレジットカードによる支払いのみに対応しております。<br />
#                 詳細については<a href="https://stripe.com/docs/payments/cards/supported-card-brands" target="_blank" rel="noopener">こちら</a
#                 >をご確認ください。
#               </p>
#             </div>
#             <div>
#               <h4>ご返金について</h4>
#               <p>
#                 規定に則りご対応致します。<br />
#                 詳細については<a href="https://tech0-jp.com/terms/#terms-6" target="_blank" rel="noopener">こちら</a
#                 >をご確認ください。
#               </p>
#             </div>
#           </div>
#         </section>
#         <!-- -------------------------------- EVENT -------------------------------- -->
#         <section id="event" class="content" style="display: none">
#           <h2 data-en-title="EVENT" data-aos="fade-left-bit">イベント情報</h2>
#           <div class="swiper">
#             <div class="panels swiper-wrapper">
#               <div class="panel swiper-slide">
#                 <img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/pic_event_dummy.jpg"
#                   alt=""
#                 />
#                 <div>
#                   <ul class="tags">
#                     <li>オンライン</li>
#                   </ul>
#                   <h3>日本の新規事業で絶対外せない３つのポイント</h3>
#                   <span class="date">2023年01月30日 (月) 18:00 〜 19:00</span>
#                   <div class="btnArea">
#                     <a href="#" class="btn invert">イベントの詳細を見る</a>
#                   </div>
#                 </div>
#               </div>
#               <div class="panel swiper-slide">
#                 <img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/pic_event_dummy.jpg"
#                   alt=""
#                 />
#                 <div>
#                   <ul class="tags">
#                     <li>オンライン</li>
#                   </ul>
#                   <h3>日本の新規事業で絶対外せない３つのポイント</h3>
#                   <span class="date">2023年01月30日 (月) 18:00 〜 19:00</span>
#                   <div class="btnArea">
#                     <a href="#" class="btn invert">イベントの詳細を見る</a>
#                   </div>
#                 </div>
#               </div>
#               <div class="panel swiper-slide">
#                 <img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/pic_event_dummy.jpg"
#                   alt=""
#                 />
#                 <div>
#                   <ul class="tags">
#                     <li>オンライン</li>
#                   </ul>
#                   <h3>日本の新規事業で絶対外せない３つのポイント</h3>
#                   <span class="date">2023年01月30日 (月) 18:00 〜 19:00</span>
#                   <div class="btnArea">
#                     <a href="#" class="btn invert">イベントの詳細を見る</a>
#                   </div>
#                 </div>
#               </div>
#               <div class="panel swiper-slide">
#                 <img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/pic_event_dummy.jpg"
#                   alt=""
#                 />
#                 <div>
#                   <ul class="tags">
#                     <li>オンライン</li>
#                   </ul>
#                   <h3>日本の新規事業で絶対外せない３つのポイント</h3>
#                   <span class="date">2023年01月30日 (月) 18:00 〜 19:00</span>
#                   <div class="btnArea">
#                     <a href="#" class="btn invert">イベントの詳細を見る</a>
#                   </div>
#                 </div>
#               </div>
#             </div>
#             <div class="swiper-pagination"></div>
#           </div>
#           <div class="btnArea">
#             <a href="#" class="btn">一覧を見る</a>
#           </div>
#         </section>
#         <!-- -------------------------------- APPLY -------------------------------- -->
#         <section id="apply" class="content">
#           <h2 data-en-title="APPLY" data-aos="fade-left-bit">応募方法</h2>
#           <p>
#             Tech0にご関心をお持ち頂きまして、ありがとうございます。<br />
#             Tech0
#             BootCampへの応募及び選考申込みの流れは、下記フローのようになります。<br />
#             申込みはLINEの友達登録よりお願い致します。
#           </p>
#           <a
#             href="https://tech0-jp.com/wp-content/uploads/2023/06/img_apply01-large.png"
#             ><img
#               src="https://tech0-jp.com/wp-content/uploads/2023/06/img_apply01.png"
#               alt="応募の流れ"
#               class="zoom"
#           /></a>
#           <div class="btnArea">
#             <a href="https://liff-gateway.lineml.jp/landing?follow=%40143yqdhm&#038;lp=XD0TNk&#038;liff_id=1657315760-N459xXV3" target="_blank" rel="noopener"><img
#                 src="https://tech0-jp.com/wp-content/uploads/2023/06/btn_reserve.svg"
#                 alt="（無料）第4期(70名)満員御礼 公式LINEからオンライン説明会を予約する"
#             /></a>
#           </div>
#         </section>
#         <!-- --------------------------------- FAQ --------------------------------- -->
#         <section id="faq" class="content">
#           <h2 data-en-title="FAQ" data-aos="fade-left-bit">よくあるご質問</h2>
#           <details>
#             <summary>Tech0とはどのようなコミュニティですか？</summary>
#             <p>
#               Tech0はGAFAMエンジニアが中心となって立ち上げた、テクノロジーを０から学びたい人のためのオンラインのテクノロジーブートキャンプです。<br />
#               従来のプログラミングスクールと異なり、参加者が勉強したい内容に応じ、現役GAFAMエンジニアをはじめとするITのプロが最適な学習方法・学習教材等をコーチングするスタイルを採用しております。<br />
#               グループによる学習スタイルも提供していますので、一人では不安な方でも安心です。
#             </p>
#           </details>
#           <details>
#             <summary>
#               具体的にはどういったスキルを身に付けることが出来るのでしょうか？
#             </summary>
#             <p>
#               本コミュニティに所属するGAFAMエンジニアの技術で対応可能なものであれば、受講者のニーズにあわせたスキルを習得可能です。<br />
#               一部ですが、具体例をあげると、Pythonのコーディングスキルやスマホアプリの作成、ビジネスの現場における業務の自動化等に取り組まれているメンバーもいます。
#             </p>
#           </details>
#           <details>
#             <summary>ITのことは全く分かりませんが大丈夫でしょうか？</summary>
#             <p>
#               Tech-0はIT未経験の方のためのコミュニティなのでご安心ください。<br />
#               実際にTech-0を加入者の方の95％以上がプログラミング未経験、90％以上が非IT企業
#               の出身者です。未経験の方に特化した教材や現役GAFAMエンジニアがサポートしておりますので、初心者の方でも安心して学べる環境です。
#             </p>
#           </details>
#           <details>
#             <summary>
#               全くの初心者のため、用語や操作についていけるかどうか不安です。
#             </summary>
#             <p>
#               経験豊富な現役GAFAMエンジニアである講師が都度丁寧にIT用語や操作について説明しますので、ご安心下さい。<br />
#               また、本コミュニティ初回参加者の90％以上が非IT企業出身者であり、挫折すること無くコミュニティに参加を頂いております。
#             </p>
#           </details>
#           <details>
#             <summary>
#               働きながらの学習でも、本当にプログラミングやITスキルの実力は身につきますか？
#             </summary>
#             <p>
#               Tech-0では、働きながら学習したい人のために、複数の学習スタイルをご用意しております。<br />
#               そのため、働きながらでもプログラミングスキルやITスキルを身につけることは可能ですのでご安心ください。<br />
#               ご要望に応じ、現役GAFAMエンジニアからのサポートやモチベーションを維持するための複数の仕組みが用意されておりますので、働きながらスキルを身につけることが可能です。
#             </p>
#           </details>
#           <details>
#             <summary>定期的に予定を確保できるかが不安です。</summary>
#             <p>
#               毎週なるべく講義やグループワーク等へ参加頂くのが、エンジニアとしてのスキルを向上させる上でベストですが、都合がつかない際は欠席頂いても問題ございません。<br />
#               その際は録画した動画を視聴いただいてキャッチアップ頂くことも可能です。
#             </p>
#           </details>
#           <details>
#             <summary>
#               週１時間の講座やミーティング以外に、学習時間はどれくらい必要でしょうか？
#             </summary>
#             <p>
#               週10時間前後を確保頂ければ、学習は可能です。<br />
#               毎日１時間ずつこつこつやられる方や週末にまとめて時間を確保する方もいらっしゃいます。
#             </p>
#           </details>
#           <details>
#             <summary>Tech0の講師のレベルはどの程度でしょうか？</summary>
#             <p>
#               原則として、講師は現役GAFAMエンジニアか、それと類する経歴をお持ちのITのプロフェッショナルを採用しております。<br />
#               また講師全員に徹底した教育研修を行っており、プログラミングを教える技術力のみならず、教育のプロとして受講生に対応いたします。
#             </p>
#           </details>
#         </section>
#         <!-- --------------------------------- NEWS --------------------------------- -->
#         <section id="news" class="content" style="display: none">
#           <h2 data-en-title="NEWS" data-aos="fade-left-bit">お知らせ</h2>
#           <dl>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >2023年6月26日 (月) 、7月4日 (火)　第6期生 オンライン説明会</a
#               >
#             </dd>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >2023年6月26日 (月) 、7月4日 (火)　第6期生 オンライン説明会</a
#               >
#             </dd>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >2023年6月26日 (月) 、7月4日 (火)　第6期生 オンライン説明会</a
#               >
#             </dd>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >2023年6月26日 (月) 、7月4日 (火)　第6期生 オンライン説明会</a
#               >
#             </dd>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >2023年6月26日 (月) 、7月4日 (火)　第6期生 オンライン説明会</a
#               >
#             </dd>
#             <dt>
#               <span class="date">2023.05.29</span
#               ><span class="tag">お知らせ</span>
#             </dt>
#             <dd>
#               <a href="#"
#                 >長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。長い文章。</a
#               >
#             </dd>
#           </dl>
#           <div class="btnArea"><a href="#" class="btn">一覧を見る</a></div>
#         </section>
#       </main>
#       <footer>
#         <img
#           src="https://tech0-jp.com/wp-content/uploads/2023/06/logo_footer.png"
#           alt="Tech 0"
#           class="logo"
#         />
#         <nav>
#           <ul>
#             <li>
#               <a href="https://tech0-jp.com/aboutus/" target="_blank" rel="noopener">私たちについて</a
#               >
#             </li>
#             <li>
#               <a href="https://tech0-jp.com/services/" target="_blank" rel="noopener">サービス</a
#               >
#             </li>
#             <li>
#               <a href="https://tech0-jp.com/companyinfo/" target="_blank" rel="noopener">会社概要</a
#               >
#             </li>
#             <li>
#               <a href="https://tech0-jp.com/contact/" target="_blank" rel="noopener">お問い合わせ</a
#               >
#             </li>
#           </ul>
#           <ul class="other">
#             <li>
#               <a href="https://tech0-jp.com/commerce/" target="_blank" rel="noopener">特定商取引法に関する表示</a
#               >
#             </li>
#             <li>
#               <a href="https://tech0-jp.com/terms/" target="_blank" rel="noopener">利用規約</a>
#             </li>
#             <li>
#               <a href="https://tech0-jp.com/privacy/" target="_blank" rel="noopener">プライバシーポリシー</a
#               >
#             </li>
#           </ul>
#           <ul class="sns">
#             <li>
#               <a href="https://twitter.com/Tech0official" target="_blank" rel="noopener"><img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/ico_twitter.svg"
#                   alt="Twitter"
#               /></a>
#             </li>
#             <li>
#               <a href="https://liff.line.me/1657315760-N459xXV3/landing?follow=%40143yqdhm&#038;lp=XD0TNk&#038;liff_id=1657315760-N459xXV3" target="_blank" rel="noopener"><img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/ico_line.svg"
#                   alt="LINE"
#               /></a>
#             </li>
#             <li>
#               <a href="https://www.linkedin.com/company/89921601" target="_blank" rel="noopener"><img
#                   src="https://tech0-jp.com/wp-content/uploads/2023/06/ico_lnkedin.svg"
#                   alt="Twitter"
#               /></a>
#             </li>
#           </ul>
#         </nav>
#         <small
#           ><a href="https://www.szlaw.jp/" target="_blank" rel="noopener">顧問法律事務所　潮見坂綜合法律事務所</a
#           ></small
#         >
#       </footer>
#     </div>
#
#
#
# <script src="https://unpkg.com/aos@2.3.1/dist/aos.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/zooming@2.1.1/build/zooming.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/swiper@9/swiper-bundle.min.js"></script>
#
#
#
# <script>
#       const toggleBodyClass = () => {
#         const bodyClass = document.getElementById("top").className;
#
#         if (bodyClass === "menu-open") {
#           document.body.classList.remove("menu-open");
#           document.getElementById("top").className = ""
#           console.log("ページの読み込みが完了しました。1");
#         } else {
#           document.body.classList.add("menu-open");
#           document.getElementById("top").className = "menu-open"
#           console.log("ページの読み込みが完了しました。2");
#         }
#       };
#
#       document.addEventListener("DOMContentLoaded", function () {
#         const btn_menu = document.querySelector(".btn_menu");
#         btn_menu.addEventListener("click", function () {
#           toggleBodyClass();
#         });
#
#         document.querySelectorAll("nav.all a").forEach(function (elm) {
#           elm.addEventListener("click", function () {
#             toggleBodyClass();
#             console.log("ページの読み込みが完了しました。");
#           });
#         });
#
#         document.querySelectorAll("summary").forEach(function (elm) {
#           elm.addEventListener("click", function () {
#             setTimeout(function () {
#               AOS.refresh();
#             }, 500);
#           });
#         });
#
#         AOS.init({
#           duration: 600,
#         });
#
#         const breakpoint = window.matchMedia("(min-width:721px)");
#         let mySwiper;
#
#         const breakpointChecker = function () {
#           if (breakpoint.matches === true) {
#             if (mySwiper !== undefined) {
#               for (const elm of mySwiper) {
#                 elm.destroy(true, true);
#               }
#             }
#             return;
#           } else if (breakpoint.matches === false) {
#             return enableSwiper();
#           }
#         };
#
#         const enableSwiper = function () {
#           mySwiper = new Swiper(".swiper", {
#             slidesPerView: "1.2",
#             spaceBetween: 25,
#             grabCursor: true,
#             pagination: {
#               el: ".swiper-pagination",
#             },
#           });
#         };
#
#         breakpoint.addListener(breakpointChecker);
#         breakpointChecker();
#
#         new Zooming({
#           scaleExtra: 1.1,
#         }).listen(".zoom");
#       });
#     </script>
# 	</div><!-- .entry-content -->
#
# </article><!-- #post-505 -->
# 	</main><!-- #main -->
#
# <img class="st-pvm-impression-tracker"
#      src="https://tech0-jp.com/st-manager/pv-monitor/impression/track?query_type_id=front_page&queried_page=1&url=https%3A%2F%2Ftech0-jp.com%2F&referrer=&u=f92184ca-b961-49ce-81dd-fdfeabfbce8b" width="1" height="1" alt=""
#      data-ogp-ignore>
# <script src='https://tech0-jp.com/wp-content/plugins/contact-form-7/includes/swv/js/index.js?ver=5.8.1' id='swv-js'></script>
# <script id='contact-form-7-js-extra'>
# var wpcf7 = {"api":{"root":"https:\/\/tech0-jp.com\/wp-json\/","namespace":"contact-form-7\/v1"}};
# </script>
# <script src='https://tech0-jp.com/wp-content/plugins/contact-form-7/includes/js/index.js?ver=5.8.1' id='contact-form-7-js'></script>
# <script src='https://tech0-jp.com/wp-content/plugins/st-pv-monitor/Resources/assets/js/shortcode.js?ver=20201211' id='st-pv-monitor-shortcode-js'></script>
# <script src='https://tech0-jp.com/wp-content/themes/allallwhite/js/navigation.js?ver=1.0.0' id='allwhite-navigation-js'></script>
# <!-- start Simple Custom CSS and JS -->
# <script>
#   function lineButton() {
#     fbq("track", "LINEclick");
#     if (location.pathname == "/ad/") {
#       gtag("event", "generate_lead", {
#         event_name: "click",
#         link_url:
#           "https://liff.line.me/1657315760-N459xXV3/landing?follow=%40143yqdhm&lp=XePeri&liff_id=1657315760-N459xXV3",
#       });
#       console.log("gta");
#     } else {
#       ga("send", {
#         hitType: "event",
#         eventCategory: "line",
#         eventAction: "click",
#         eventLabel: "test",
#         eventValue: 1,
#       });
#       console.log("ga");
#     }
#   }
# </script><!-- end Simple Custom CSS and JS -->
#
# </body>
# </html>

# %% [markdown]
# #### 楽天からデータを取得してみましょう

# %% [markdown]
# 楽天側が用意した仕様に沿ったアクセス先とリクエストパラメータを設定していきましょう！
# アクセス先とAPIキーとパラメーターを設定します

# %%
# アクセス先と認証IDと要求するデータを指定します。
REQUEST_URL = "https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426"
 #アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
APP_ID = "1090380199694035412"

# %%
# param
params = {
    'format': 'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': '1090380199694035412'
}

# %% [markdown]
# requests.get(アクセス先, リクエストパラメータ)を指定して、APIサーバーにデーターを要求しましょう！

# %%
# resにリクエストして得られた結果を代入します。
res = requests.get(REQUEST_URL, params)

# %% [markdown]
# リクエストが成功したか、ステータスの数字で確認しましょう！
# - 200なら正常に通信完了
# - 404ならアクセス先が間違えています。
# - その他の400番台はパラメータが間違えています！

# %%
#変数だけを指定する事でprint()を省略できます。
res
# Out:
# <Response [200]>

# %% [markdown]
# 通信の結果、返ってきたデータの中身を変数resultにjsonとして格納してから確認してみましょう！
# res.json()とすることで、レスポンスデータの中にあるjsonデータをしてすることができます。

# %%
# resultにresの中にあるjsonデータを代入します。
result = res.json()

# 代入したデータを見てみましょう。
result
# Out:
# {'pagingInfo': {'recordCount': 416,
#   'pageCount': 14,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 182884,
#       'hotelName': 'ホテルリソルトリニティ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182884',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182884',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884',
#       'hotelKanaName': 'ほてるりぞるとりにてぃなは',
#       'hotelSpecial': '2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。',
#       'hotelMinCharge': 4200,
#       'latitude': 94341.93,
#       'longitude': 459641.13,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町7',
#       'telephoneNo': '098-863-9269',
#       'faxNo': '098-863-9279',
#       'access': 'ゆいレール「旭橋駅」出入口2より徒歩3分',
#       'parkingInformation': '機械式立体駐車場50台1泊1,500円 ※台風・災害時など利用不可※先着順予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182884.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884map.gif',
#       'reviewCount': 243,
#       'reviewAverage': 4.4,
#       'userReview': 'あまり広いお部屋ではないですが、木を基調とした柔らかい雰囲気で清潔感があり、とても居心地がよかったです。大浴場は、タイルが光に当たるととても綺麗で、旅の疲れが癒やされました。とにかく内装がとて…\u30002023-10-12 11:47:19投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.14,
#       'locationAverage': 4.39,
#       'roomAverage': 4.38,
#       'equipmentAverage': 4.21,
#       'bathAverage': 4.28,
#       'mealAverage': 4.37}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 128440,
#       'hotelName': 'ダイワロイネットホテル那覇国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=128440',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=128440&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=128440',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440',
#       'hotelKanaName': 'だいわろいねっと\u3000なはこくさいどおり',
#       'hotelSpecial': '国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪',
#       'hotelMinCharge': 3830,
#       'latitude': 94369.8,
#       'longitude': 459703.77,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2-1-1',
#       'telephoneNo': '098-868-9055',
#       'faxNo': '098-868-9056',
#       'access': 'ゆいレール「牧志」駅直結！！那覇空港からモノレールで約20分♪',
#       'parkingInformation': '当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/128440.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440_sin.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/128440.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440map.gif',
#       'reviewCount': 1465,
#       'reviewAverage': 4.37,
#       'userReview': 'まず立地が抜群に良いです。天気悪くてもゆいレール牧志駅から屋根付きの連絡通路があり安心です。国際通りが出て目の前ですので便利です。部屋は上層階の角部屋でした。長めも良く、部屋もクイーンベッド？…\u30002023-10-03 14:21:44投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.13,
#       'locationAverage': 4.76,
#       'roomAverage': 4.28,
#       'equipmentAverage': 4.03,
#       'bathAverage': 3.63,
#       'mealAverage': 4.36}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 134763,
#       'hotelName': 'ダイワロイネットホテル那覇おもろまち',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=134763',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=134763',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763',
#       'hotelKanaName': 'だいわろいねっとほてるなはおもろまち',
#       'hotelSpecial': '海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎',
#       'hotelMinCharge': 3800,
#       'latitude': 94389.24,
#       'longitude': 459709.57,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち1-1-12',
#       'telephoneNo': '098-862-4555',
#       'faxNo': '098-862-4556',
#       'access': 'ゆいレール\u3000おもろまち駅より徒歩５分\u3000国際通りより車で5分',
#       'parkingInformation': '1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用下さい。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/134763.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763_tw.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/134763.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763map.gif',
#       'reviewCount': 997,
#       'reviewAverage': 4.49,
#       'userReview': '初めて利用しました非常に清潔、快適で素晴らしかったですまた利用したいホテルです\u30002023-10-14 14:58:11投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.23,
#       'locationAverage': 4.28,
#       'roomAverage': 4.55,
#       'equipmentAverage': 4.23,
#       'bathAverage': 3.93,
#       'mealAverage': 4.12}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 148000,
#       'hotelName': 'ハイアットリージェンシー那覇沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=148000',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=148000&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=148000',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=148000',
#       'hotelKanaName': 'はいあっとりーじぇんしーなはおきなわ',
#       'hotelSpecial': 'グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。',
#       'hotelMinCharge': 7926,
#       'latitude': 94357.69,
#       'longitude': 459690.88,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-6-20',
#       'telephoneNo': '098-866-8888',
#       'faxNo': '098-866-8111',
#       'access': '那覇空港から車で約２０分、ゆいレール「牧志駅」から徒歩７分 、国際通りまで徒歩3分',
#       'parkingInformation': '立体駐車場・地下駐車場完備\u3000１１３台\u30001泊1台あたり1,500円（税込）\u3000（予約不要／出し入れ自由）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/148000.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000_kan.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/148000.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000map.gif',
#       'reviewCount': 633,
#       'reviewAverage': 4.64,
#       'userReview': 'クラブアクセス付きにして大正解。お部屋も綺麗で快適でした。対応していただいたスタッフの皆様に感謝します。ありがとうございました。\u30002023-09-23 15:27:19投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.65,
#       'locationAverage': 4.55,
#       'roomAverage': 4.71,
#       'equipmentAverage': 4.66,
#       'bathAverage': 4.19,
#       'mealAverage': 4.56}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 16443,
#       'hotelName': 'ロワジールホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=16443',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=16443&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=16443',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443',
#       'hotelKanaName': 'ろわじーるほてるなは',
#       'hotelSpecial': '空港から車で約7分。天然温泉大浴場、室内外プールと館内施設が充実♪■楽天認定プレミアムホテル■',
#       'hotelMinCharge': 5142,
#       'latitude': 94355.14,
#       'longitude': 459603.97,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1台1,800円',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/16443.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/16443.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443map.gif',
#       'reviewCount': 1351,
#       'reviewAverage': 3.93,
#       'userReview': '沖縄のリーズナブルなホテルは総じてですが、大浴場はそこまでよくありません。が、十分疲れが取れるレベルです。ご飯は種類も多く、とてもおいしいです。部屋はスーツケースをギリギリ開ける大きさですが、立地…\u30002023-10-10 16:40:56投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.72,
#       'locationAverage': 3.81,
#       'roomAverage': 3.82,
#       'equipmentAverage': 3.73,
#       'bathAverage': 3.88,
#       'mealAverage': 3.87}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181785,
#       'hotelName': 'ヒューイットリゾート那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181785',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181785&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181785',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785',
#       'hotelKanaName': 'ひゅーいっとりぞーとなは',
#       'hotelSpecial': '2021年7月15日OPEN！朝食ブッフェは宿泊の皆様に無料でご提供いたします！',
#       'hotelMinCharge': 5110,
#       'latitude': 94371.18,
#       'longitude': 459711.73,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2丁目5番16号',
#       'telephoneNo': '098-943-8325',
#       'faxNo': '098-943-8326',
#       'access': 'モノレール安里駅から徒歩3分\u3000バス国内線旅客ターミナル発120番安里下車徒歩3分\u3000タクシー那覇空港より約20分',
#       'parkingInformation': '有り\u300084台\u30001,650円（税込）/泊',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181785.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785map.gif',
#       'reviewCount': 270,
#       'reviewAverage': 4.29,
#       'userReview': '高級宿の表記もあり、口コミを見て予約しましたが見た目綺麗なビジネスホテルという感じでした。枕やシーツに髪の毛が数本落ちておりとても気になりました。部屋の温度も寒く、部屋のリモコンで…\u30002023-10-06 19:15:47投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.02,
#       'locationAverage': 4.5,
#       'roomAverage': 4.25,
#       'equipmentAverage': 3.96,
#       'bathAverage': 3.98,
#       'mealAverage': 4.21}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 104526,
#       'hotelName': 'ダイワロイネットホテル沖縄県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=104526',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=104526&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=104526',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=104526',
#       'hotelKanaName': 'だいわろいねっとほてるおきなわけんちょうまえ',
#       'hotelSpecial': '那覇空港より１５分。県庁等官庁街へ徒歩２分、人気の国際通りへは徒歩３分でビジネス・観光に好立地。',
#       'hotelMinCharge': 4500,
#       'latitude': 94353.12,
#       'longitude': 459642.44,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-2',
#       'telephoneNo': '098-860-1855',
#       'faxNo': '098-860-1856',
#       'access': '◆モノレール県庁前駅または旭橋駅 徒歩3分\u3000◆那覇空港 モノレール13分、車で約10分\u3000◆沖縄県庁、国際通り 徒歩3分',
#       'parkingInformation': '有り\u3000１台\u3000１０５０円（税込み／泊）\u3000先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/104526.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/104526.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526map.gif',
#       'reviewCount': 1152,
#       'reviewAverage': 4.19,
#       'userReview': '近くにコンビニもあり、助かります。モノレールも近いので、空港へのアクセスもいいです。デスクが大きく、仕事もしやすかったです。\u30002023-10-11 11:23:21投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.87,
#       'locationAverage': 4.32,
#       'roomAverage': 4.23,
#       'equipmentAverage': 3.9,
#       'bathAverage': 3.78,
#       'mealAverage': 3.41}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 177761,
#       'hotelName': '東急ステイ沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=177761',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=177761&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=177761',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761',
#       'hotelKanaName': 'とうきゅうすてい\u3000おきなわ\u3000なは',
#       'hotelSpecial': '食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチン完備！',
#       'hotelMinCharge': 5550,
#       'latitude': 94334.89,
#       'longitude': 459646.33,
#       'postalCode': '900-0025',
#       'address1': '沖縄県',
#       'address2': '那覇市壷川3-2-1',
#       'telephoneNo': '098-833-1090',
#       'faxNo': '098-833-1091',
#       'access': '沖縄都市モノレール線\u3000壷川駅より徒歩にて約３分',
#       'parkingInformation': '屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に料金発生',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177761.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761map.gif',
#       'reviewCount': 570,
#       'reviewAverage': 4.48,
#       'userReview': '立地がいい。下にドンキーがあるのもまたいいです。\u30002023-09-30 12:34:22投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.23,
#       'locationAverage': 4.52,
#       'roomAverage': 4.55,
#       'equipmentAverage': 4.28,
#       'bathAverage': 3.98,
#       'mealAverage': 4.33}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 167519,
#       'hotelName': 'ノボテル沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=167519',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=167519&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=167519',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519',
#       'hotelKanaName': 'のぼてる\u3000おきなわ\u3000なは',
#       'hotelSpecial': '国際通りから車で約５分、那覇にいてもリゾート気分を！クラブラウンジやインフィニティプールがあるホテル',
#       'hotelMinCharge': 5850,
#       'latitude': 94374.6,
#       'longitude': 459750.57,
#       'postalCode': '902-0062',
#       'address1': '沖縄県',
#       'address2': '那覇市松川40番地',
#       'telephoneNo': '098-887-1111',
#       'faxNo': '098-886-5591',
#       'access': '那覇空港から車で約25分、ゆいレール安里駅よりタクシーで約５分／徒歩約２０分',
#       'parkingInformation': '有り（1泊1台1,000円）\u3000※事前予約不可',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167519.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/167519.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519map.gif',
#       'reviewCount': 383,
#       'reviewAverage': 4.4,
#       'userReview': '綺麗なホテルでサービスも◎テラス付きの部屋にしました。素敵でした。テラスの椅子が少し汚れてたのと濡れてたので何か敷くものがあったら更に良かったです！ラウンジも素敵でよかったですし、サービス…\u30002023-09-10 09:49:34投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.39,
#       'locationAverage': 3.87,
#       'roomAverage': 4.35,
#       'equipmentAverage': 4.23,
#       'bathAverage': 4.08,
#       'mealAverage': 4.18}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 176757,
#       'hotelName': '沖縄ハーバービューホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=176757',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=176757&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=176757',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=176757',
#       'hotelKanaName': 'おきなわはーばーびゅーほてる',
#       'hotelSpecial': '楽天トラベルからのご予約限定☆楽天専用ラウンジOPEN☆お飲み物やアメニティをご用意しております',
#       'hotelMinCharge': 3375,
#       'latitude': 94336.98,
#       'longitude': 459657.29,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎2-46',
#       'telephoneNo': '098-853-2111',
#       'faxNo': '098-835-9696',
#       'access': '那覇空港より車で10分・ゆいレール壷川駅/旭橋駅より徒歩約10分/国際通りまで徒歩約10分',
#       'parkingInformation': '有り\u3000１９０台\u3000１８００円（税込み／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/176757.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/176757.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757map.gif',
#       'reviewCount': 483,
#       'reviewAverage': 4.27,
#       'userReview': '地元民です。クラブラウンジ付プランを利用しました。ゆっくりとホテルステイでき満足しています。次は遠方に住む両親と一緒に宿泊したいと思います。\u30002023-10-02 20:47:22投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.12,
#       'locationAverage': 3.84,
#       'roomAverage': 4.29,
#       'equipmentAverage': 4.07,
#       'bathAverage': 3.83,
#       'mealAverage': 4.13}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178447,
#       'hotelName': 'ＨＯＴＥＬ\u3000ＳＡＮＳＵＩ\u3000ＮＡＨＡ\u3000琉球温泉\u3000波之上の湯',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178447',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178447&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178447',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178447',
#       'hotelKanaName': 'ほてる\u3000さんすい\u3000なは\u3000りゅうきゅうおんせん\u3000なみのうえおんせん',
#       'hotelSpecial': '癒しの波上温泉とシースループール完備で那覇空港に一番近いスパ＆リゾート',
#       'hotelMinCharge': 4386,
#       'latitude': 94372.73,
#       'longitude': 459616.75,
#       'postalCode': '900-0037',
#       'address1': '沖縄県',
#       'address2': '那覇市辻2-25-1',
#       'telephoneNo': '0120-996-941',
#       'faxNo': '098-894-7303',
#       'access': '空港から車で約8分◆ホテルと那覇空港を結ぶシャトルバスも運行中◆崖の上の「縁結びパワースポット」波上宮まで【徒歩4分】',
#       'parkingInformation': '有り\u300042台\u30001,500円（税込み／泊）\u3000先着順\u3000※高さ制限有（175センチ）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178447.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447map.gif',
#       'reviewCount': 259,
#       'reviewAverage': 4.14,
#       'userReview': '朝食が沢山あり、どれも美味しかったです。\u30002023-10-06 22:45:55投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.94,
#       'locationAverage': 3.35,
#       'roomAverage': 3.91,
#       'equipmentAverage': 3.96,
#       'bathAverage': 4.2,
#       'mealAverage': 4.29}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 71990,
#       'hotelName': 'ホテル\u3000ロコア\u3000ナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=71990',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=71990&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=71990',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990',
#       'hotelKanaName': 'ろこあ\u3000なは',
#       'hotelSpecial': '目の前が国際通り！空港直通ゆいレール駅から徒歩2分！朝食バイキングは口コミでも高評価♪',
#       'hotelMinCharge': 4600,
#       'latitude': 94354.63,
#       'longitude': 459657.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-1-2',
#       'telephoneNo': '098-868-6578',
#       'faxNo': '098-868-6521',
#       'access': 'モノレール\u3000県庁前駅より徒歩２分',
#       'parkingInformation': '提携駐車場１泊1台１5００円。営業時間外の入出庫不可。先着順。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/71990.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/71990.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990map.gif',
#       'reviewCount': 1742,
#       'reviewAverage': 4.36,
#       'userReview': '朝食がとにかくおいしいです。沖縄のいろいろな特産物があり、品数も豊富です。デザートのフルーツ類がめちゃくちゃ美味しかったです。また、泊まりたいです。\u30002023-10-14 17:32:25投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.18,
#       'locationAverage': 4.71,
#       'roomAverage': 4.16,
#       'equipmentAverage': 4.02,
#       'bathAverage': 3.61,
#       'mealAverage': 4.45}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 163087,
#       'hotelName': 'ホテルアクアチッタナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=163087',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=163087&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=163087',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=163087',
#       'hotelKanaName': 'ほてるあくあちったなは',
#       'hotelSpecial': 'シースループール◆那覇の夜景を望めるナイトプールが人気◆地中海の朝市をコンセプトにした朝食',
#       'hotelMinCharge': 4464,
#       'latitude': 94385.53,
#       'longitude': 459666.2,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-2-20',
#       'telephoneNo': '0120-996-941',
#       'faxNo': '098-866-5600',
#       'access': '泊港離島ターミナルより徒歩30秒/美栄橋駅より徒歩7分/国際通りより徒歩約10分/那覇空港より車で約15分/国道58号沿',
#       'parkingInformation': '有 60台 1,200円（税込／泊）高さ制限1.55ｍ ※先着順\u3000その他のお車は近隣駐車場をご案内',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/163087.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/163087.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087map.gif',
#       'reviewCount': 354,
#       'reviewAverage': 4.32,
#       'userReview': '全体的に綺麗です。フロント対応も良くてまた使いたいと思います。\u30002023-10-09 10:12:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.05,
#       'locationAverage': 4.17,
#       'roomAverage': 4.14,
#       'equipmentAverage': 4,
#       'bathAverage': 3.8,
#       'mealAverage': 4.5}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178292,
#       'hotelName': 'ホテル\u3000ストレータ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292',
#       'hotelKanaName': 'すとれーたなは',
#       'hotelSpecial': '「美栄橋」から、新しい沖縄らしさを育み、発信していく場所となっていくことを目指しています。',
#       'hotelMinCharge': 4250,
#       'latitude': 94373.92,
#       'longitude': 459670.45,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志1丁目19番8号',
#       'telephoneNo': '098-860-7400',
#       'faxNo': '098-860-7410',
#       'access': 'ゆいレール「美栄橋駅」より徒歩30秒｜那覇空港より車で約16分｜国際通りまで徒歩約5分',
#       'parkingInformation': '立体駐車場48台：\\1,500/1泊\u3000到着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178292.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292map.gif',
#       'reviewCount': 205,
#       'reviewAverage': 4.45,
#       'userReview': '駅近なので移動に困りません。駐車場は立体なので大きな荷物はエントランスで荷下ろしがベスト。タオルは人数分のみなので、大きなバスタブで複数回の入浴はタオルの追加を有料で手配できます。スイート…\u30002023-09-26 13:48:00投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.22,
#       'locationAverage': 4.89,
#       'roomAverage': 4.25,
#       'equipmentAverage': 4.04,
#       'bathAverage': 3.77,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 149369,
#       'hotelName': 'ホテルグレイスリー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=149369',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=149369&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=149369',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=149369',
#       'hotelKanaName': 'ぐれいすりーなは',
#       'hotelSpecial': '★国際通り徒歩0分！★バス・トイレ別で、観光・出張も快適に♪焼きたてあぐー豚が人気の朝食ビュッフェ',
#       'hotelMinCharge': 5000,
#       'latitude': 94356.9,
#       'longitude': 459663.7,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-3-6',
#       'telephoneNo': '098-867-6111',
#       'faxNo': '098-867-4311',
#       'access': '●ゆいレール「県庁前」駅徒歩5分／●「国際通り」徒歩0分。荷物が多くても、車が無くても楽々♪',
#       'parkingInformation': '近隣（徒歩5分ほど）のコインパーキングをご案内します。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/149369.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/149369.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369map.gif',
#       'reviewCount': 592,
#       'reviewAverage': 4.5,
#       'userReview': '食事は外で頂く予定だったので、お部屋だけで宿泊しましたが立地も含めて大満足です(^^)また、行く時はお世話になりたいと思います。\u30002023-10-12 18:58:55投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.3,
#       'locationAverage': 4.71,
#       'roomAverage': 4.38,
#       'equipmentAverage': 4.11,
#       'bathAverage': 4.53,
#       'mealAverage': 4.36}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 136808,
#       'hotelName': 'リーガロイヤルグラン沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=136808',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=136808&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=136808',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808',
#       'hotelKanaName': 'りーがろいやるぐらんおきなわ',
#       'hotelSpecial': '【エントリーと予約でポイント増量参画中】「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド',
#       'hotelMinCharge': 7466,
#       'latitude': 94344.0,
#       'longitude': 459638.85,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町1-9',
#       'telephoneNo': '098-867-3331',
#       'faxNo': '098-867-3332',
#       'access': '【那覇空港から】車で約５分、ゆいレール「旭橋駅」下車\u3000駅から直結 【那覇バスターミナル】徒歩２分 【国際通り】徒歩１０分',
#       'parkingInformation': '有り\u3000料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/136808.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/136808.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808map.gif',
#       'reviewCount': 615,
#       'reviewAverage': 4.67,
#       'userReview': '今回初めて利用しましたが、ラグジュアリー感、清潔感、部屋も綺麗で最高でした!!スタッフさんの対応も良く、親切にして頂きありがとうございました!!お部屋のバスタブがとにかく良かったです。また那覇に宿泊す…\u30002023-09-30 13:22:14投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.58,
#       'locationAverage': 4.74,
#       'roomAverage': 4.52,
#       'equipmentAverage': 4.66,
#       'bathAverage': 4.61,
#       'mealAverage': 4.43}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 18195,
#       'hotelName': 'サンプラザホテル＜沖縄県＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=18195',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=18195&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=18195',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195',
#       'hotelKanaName': 'さんぷらざほてる＜おきなわけん＞',
#       'hotelSpecial': 'ゆいレール牧志駅から徒歩5分。那覇のメインストリート国際通り近く、大浴場・コインランドリー有。',
#       'hotelMinCharge': 2000,
#       'latitude': 94378.86,
#       'longitude': 459694.79,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里138',
#       'telephoneNo': '098-866-0920',
#       'faxNo': '098-866-0929',
#       'access': '那覇空港から車で約15分・モノレール牧志駅から徒歩5分・崇元寺バス停前徒歩0分',
#       'parkingInformation': '有り\u3000先着順40台予約不可￥1000/泊※バス・大型車などの駐車は電話でお問合せ下さい。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/18195.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195_y.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/18195.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195map.gif',
#       'reviewCount': 2751,
#       'reviewAverage': 4.14,
#       'userReview': '1人なのにツインの洋室と和室のある広い部屋でした。大浴場は快適でサッパリしました。部屋にドライヤーが無い事だけが残念でしたが、朝食付きでこの価格は非常にリーズナブルだと思います。\u30002023-10-08 12:57:59投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.08,
#       'locationAverage': 4.22,
#       'roomAverage': 3.78,
#       'equipmentAverage': 3.56,
#       'bathAverage': 4.12,
#       'mealAverage': 3.81}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 38282,
#       'hotelName': 'ホテルパームロイヤルNAHA国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=38282',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=38282&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=38282',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282',
#       'hotelKanaName': 'ぱーむろいやる\u3000なは\u3000こくさいどおり',
#       'hotelSpecial': '＼国際通りから一歩入ると現れる楽園／ナノ水ロイヤルスパや朝食KUNCHIめしも人気',
#       'hotelMinCharge': 4100,
#       'latitude': 94365.08,
#       'longitude': 459689.04,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-9-10',
#       'telephoneNo': '098-865-5551',
#       'faxNo': '098-866-7711',
#       'access': '【ゆいレール】牧志駅下車徒歩4分（那覇空港から約25分）／【車】那覇空港より車で約15分\u3000',
#       'parkingInformation': '【有り：60台】1泊1100円（税込）満車の場合は近隣のコインパーキングをご利用下さい。※先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/38282.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/38282.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282map.gif',
#       'reviewCount': 2273,
#       'reviewAverage': 4.31,
#       'userReview': 'ビジネス利用ではありますが、定期的にこちらにお世話になっています。周辺にはハイアットやJR九州ホテル、JALシティなどのラグジュアリー系のホテルもありますが、やはりアットホーム感や柔軟性、カジュア…\u30002023-10-03 21:18:06投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.36,
#       'locationAverage': 4.79,
#       'roomAverage': 4.19,
#       'equipmentAverage': 4.2,
#       'bathAverage': 4.31,
#       'mealAverage': 4.23}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 171943,
#       'hotelName': '沖縄かりゆしリゾートエグゼス那覇＜県庁前＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=171943',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=171943&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=171943',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943',
#       'hotelKanaName': 'おきなわ\u3000かりゆし\u3000りぞーと\u3000えぐぜす\u3000なは',
#       'hotelSpecial': '那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）',
#       'hotelMinCharge': 8920,
#       'latitude': 94353.21,
#       'longitude': 459643.86,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-5',
#       'telephoneNo': '098-860-3300',
#       'faxNo': '098-860-3450',
#       'access': '那覇空港から車で約10分。モノレールご利用の場合は那覇空港駅→県庁前駅13分、下車、徒歩約4分。',
#       'parkingInformation': '有り\u3000４２台\u3000１５００円（税込／泊）\u3000満車の場合は周辺のコインパーキングをご利用くださいませ。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/171943.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943map.gif',
#       'reviewCount': 112,
#       'reviewAverage': 4.61,
#       'userReview': '前回同様プール付きの部屋を利用しました。観光目的ではなく部屋でのんびりするためにお世話になりました。朝食の片付けタイミングがスタッフによって違い、前回利用した際に、男性スタッフの方がチャイムを鳴らして…\u30002023-09-15 17:27:22投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.56,
#       'locationAverage': 4.58,
#       'roomAverage': 4.67,
#       'equipmentAverage': 4.43,
#       'bathAverage': 4.48,
#       'mealAverage': 4.62}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 130025,
#       'hotelName': '西鉄リゾートイン那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=130025',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=130025&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=130025',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=130025',
#       'hotelKanaName': 'にしてつりぞーといんなは',
#       'hotelSpecial': 'ゆいレール県庁前駅から徒歩３分。歩いて国際通りへ、便利なアクセス♪',
#       'hotelMinCharge': 4200,
#       'latitude': 94361.44,
#       'longitude': 459645.53,
#       'postalCode': '900-0033',
#       'address1': '沖縄県',
#       'address2': '那覇市久米2-3-13',
#       'telephoneNo': '098-869-5454',
#       'faxNo': '098-869-5455',
#       'access': '那覇空港からゆいレールで6駅目「県庁前駅」から徒歩約3分！国道58号沿い、国際通りへ徒歩5分！繁華街「松山」まで徒歩5分',
#       'parkingInformation': '有り４０台（先着順）１，２００円/泊。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/130025.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025_rm1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/130025.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/130025/130025map.gif',
#       'reviewCount': 809,
#       'reviewAverage': 4.32,
#       'userReview': 'エアコンの温度調整に苦労しました。\u30002023-10-10 08:31:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.1,
#       'locationAverage': 4.62,
#       'roomAverage': 4.14,
#       'equipmentAverage': 3.94,
#       'bathAverage': 4.04,
#       'mealAverage': 4.05}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 67292,
#       'hotelName': 'アパホテル〈那覇〉',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=67292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=67292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=67292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=67292',
#       'hotelKanaName': 'あぱほてる\u3000なは',
#       'hotelSpecial': '沖縄最大の繁華街奇跡の1マイルと評される「国際通り」徒歩9分、疲れた体は大浴場（無料）で癒せます',
#       'hotelMinCharge': 3600,
#       'latitude': 94371.2,
#       'longitude': 459655.92,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山1-4-16',
#       'telephoneNo': '098-868-9111',
#       'faxNo': '098-868-9411',
#       'access': '那覇空港から車で最短10分、ゆいレール（モノレール）「県庁前」または「美栄橋」駅から徒歩約7分 新都心へは車で10分',
#       'parkingInformation': '立体駐車場先着順46台1泊1,500円 【車高1.8m制限有】※新規入庫は23時迄\u3000',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/67292.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292_yo.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/67292.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/67292/67292map.gif',
#       'reviewCount': 2538,
#       'reviewAverage': 3.97,
#       'userReview': 'よかった\u30002023-10-08 13:05:45投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.96,
#       'locationAverage': 4.26,
#       'roomAverage': 3.67,
#       'equipmentAverage': 3.8,
#       'bathAverage': 3.77,
#       'mealAverage': 4.1}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 19934,
#       'hotelName': 'リッチモンドホテル那覇久茂地',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=19934',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=19934&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=19934',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=19934',
#       'hotelKanaName': 'りっちもんど\u3000なは\u3000くもじ',
#       'hotelSpecial': '国際通りやケラマ諸島へのアクセス泊港へも徒歩でOK◎美栄橋駅より徒歩２分☆1階セブンイレブンが便利',
#       'hotelMinCharge': 3170,
#       'latitude': 94378.89,
#       'longitude': 459664.07,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地2-23-12',
#       'telephoneNo': '098-869-0077',
#       'faxNo': '098-862-0088',
#       'access': '那覇空港より沖縄都市モノレール（ゆいレール）１４分、美栄橋(みえばし)駅下車徒歩約２分\u3000国道５８号線前島交差点沿い',
#       'parkingInformation': '立体駐車場(車高2ｍ)1泊 1台1,000円 ※先着順でご利用いただけます(予約制ではございません)',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/19934/19934.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/19934.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/19934/19934map.gif',
#       'reviewCount': 3681,
#       'reviewAverage': 4.18,
#       'userReview': '大満足です。朝食美味しかったです。また利用したいです。\u30002023-10-03 18:38:52投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.89,
#       'locationAverage': 4.15,
#       'roomAverage': 4.13,
#       'equipmentAverage': 3.71,
#       'bathAverage': 3.52,
#       'mealAverage': 4.08}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 40768,
#       'hotelName': 'アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=40768',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=40768&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=40768',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=40768',
#       'hotelKanaName': 'あるもんとほてるなはおもろまち',
#       'hotelSpecial': '２０２０年４月１日から『アルモントホテル那覇おもろまち』へリブランド',
#       'hotelMinCharge': 3700,
#       'latitude': 94395.88,
#       'longitude': 459713.63,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち4-3-8',
#       'telephoneNo': '098-860-6611',
#       'faxNo': '098-860-6711',
#       'access': 'ゆいレール「おもろまち駅」下車徒歩4分／Tギャラリア沖縄まで徒歩4分／サンエー那覇メインプレイス向い',
#       'parkingInformation': '有り\u300030台\u30001,100円（税込／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/40768.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/40768.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/40768/40768map.gif',
#       'reviewCount': 1512,
#       'reviewAverage': 4.54,
#       'userReview': '朝食が美味しいホテルだと口コミがあったので宿泊しました。とても美味しかったです！エレベーター内はいい匂いがしていたのですが、お部屋が若干カビ臭くて...備え付けのスプレーしても効果なし…\u30002023-10-08 18:34:14投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=40768" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.35,
#       'locationAverage': 4.51,
#       'roomAverage': 4.13,
#       'equipmentAverage': 4.13,
#       'bathAverage': 4.32,
#       'mealAverage': 4.84}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 78094,
#       'hotelName': 'ロワジールスパタワー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=78094',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=78094&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=78094',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094',
#       'hotelKanaName': 'ろわじーるすぱたわーなは',
#       'hotelSpecial': '天然温泉を24時間楽しめる客室有！全室バルコニー付、24時間利用できるフィットネスジム完備',
#       'hotelMinCharge': 7968,
#       'latitude': 94353.28,
#       'longitude': 459606.91,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1,800円/台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/78094.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/78094.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094map.gif',
#       'reviewCount': 480,
#       'reviewAverage': 3.96,
#       'userReview': '部屋に入る前から嫌な思いばかりでした。まずチェックイン前の時間に到着して行列、1時間近く並びました。さすがに怒りましたが、さらにチェックイン時にも部屋の準備ができてないので待っててくれと。部屋の前…\u30002023-09-20 11:17:46投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.79,
#       'locationAverage': 3.77,
#       'roomAverage': 4,
#       'equipmentAverage': 4.2,
#       'bathAverage': 4.47,
#       'mealAverage': 3.92}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 43753,
#       'hotelName': 'ソルヴィータホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=43753',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=43753&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=43753',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=43753',
#       'hotelKanaName': 'そるう゛ぃーたほてるなは',
#       'hotelSpecial': '宿泊者専用ラウンジあり、アイスやドリンクあり。小学生まで添い寝利用可！タオルやキッズアメニティ無料！',
#       'hotelMinCharge': 3450,
#       'latitude': 94376.95,
#       'longitude': 459651.54,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山2丁目17-17',
#       'telephoneNo': '098-863-1234',
#       'faxNo': '098-863-6911',
#       'access': '那覇空港より車で約8分ゆいレール県庁前駅・美栄橋駅・パレット久茂地より徒歩約10分！泊港（とまりん）より徒歩約5分！',
#       'parkingInformation': '有り\u300040台（1500円／泊  ）先着順・予約不可\u3000平面駐車場で出し入れラクラク',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/43753.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753_kya1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/43753.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/43753/43753map.gif',
#       'reviewCount': 1648,
#       'reviewAverage': 4.5,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 160939,
#       'hotelName': 'ＪＲ九州ホテル\u3000ブラッサム那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=160939',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=160939&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=160939',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939',
#       'hotelKanaName': 'じぇいあーるきゅうしゅうほてる\u3000ぶらっさむなは',
#       'hotelSpecial': '国際通りむつみ橋交差点徒歩1分。ゆいレール美栄橋駅徒歩５分。',
#       'hotelMinCharge': 7200,
#       'latitude': 94367.2,
#       'longitude': 459682.25,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2丁目16番１号',
#       'telephoneNo': '098-861-8700',
#       'faxNo': '098-862-8739',
#       'access': '那覇空港よりタクシーで約15分、ゆいレール\u3000美栄橋駅より徒歩にて約５分',
#       'parkingInformation': '有り\u3000１１２台\u3000１５００円（税込み／泊）\u3000予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/160939.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/160939.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939map.gif',
#       'reviewCount': 419,
#       'reviewAverage': 4.38,
#       'userReview': '雨の日は無料の傘を貸し出しされているので助かりました。部屋のホコリが落ちて掃除をしました。どこも人手不足なのでよしとしましょう。立地場所はお気に入りなので、また今度も宿泊したいです。\u30002023-10-11 13:10:06投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.07,
#       'locationAverage': 4.67,
#       'roomAverage': 4.46,
#       'equipmentAverage': 4.16,
#       'bathAverage': 4.44,
#       'mealAverage': 4.11}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 184913,
#       'hotelName': 'Ｓｏｕｔｈｗｅｓｔ\u3000Ｇｒａｎｄ\u3000Ｈｏｔｅｌ（２０２３年６月２０日新規開業）',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=184913',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=184913&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=184913',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=184913',
#       'hotelKanaName': 'さうすうえすとぐらんどほてる',
#       'hotelSpecial': '【2023年6月開業！】楽天限定開業記念プラン販売中！',
#       'hotelMinCharge': 13750,
#       'latitude': 94361.9,
#       'longitude': 459667.77,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地3-29-52',
#       'telephoneNo': '098-860-0421',
#       'faxNo': '098-860-0411',
#       'access': '・ゆいレールご利用：「県庁前」駅から徒歩約5分\u3000・タクシーご利用：那覇空港から約12分',
#       'parkingInformation': 'あり\u300010台\u30001500円（税込／泊）\u3000先着順\u3000※満車の場合は近隣のコインパーキングをご利用ください',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184913/184913.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/184913.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/184913/184913map.gif',
#       'reviewCount': 6,
#       'reviewAverage': 4.33,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181957,
#       'hotelName': 'ＯＭＯ５沖縄那覇\u3000ｂｙ\u3000星野リゾート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181957',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181957&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181957',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957',
#       'hotelKanaName': 'おも５\u3000おきなわなは\u3000ばい\u3000ほしのりぞーと',
#       'hotelSpecial': '国際通りから徒歩8分の好アクセス★寝るだけでは終わらせない、旅のテンションをあげるホテル',
#       'hotelMinCharge': 3200,
#       'latitude': 94368.45,
#       'longitude': 459654.1,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山１丁目3-16',
#       'telephoneNo': '05031348095',
#       'faxNo': '098-869-3787',
#       'access': '県庁前駅より徒歩6分、美栄橋駅より徒歩8分。那覇空港より車8分で国際通り至近',
#       'parkingInformation': '立体駐車場44台（1泊￥1500・車高1.9Mまで）先着順10:00PM〜6:00AMは入出庫不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181957.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957map.gif',
#       'reviewCount': 90,
#       'reviewAverage': 4.26,
#       'userReview': 'お部屋の雰囲気もよく、国際通りからもアクセスしやすく大変良かったです。近くにコンビニもあり、すぐに買い出しに行くこともできました。チェックアウトも自身ですぐに行うことができ、待ち時間もなくスムーズに使…\u30002023-10-14 11:44:56投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.97,
#       'locationAverage': 4.14,
#       'roomAverage': 4.28,
#       'equipmentAverage': 3.83,
#       'bathAverage': 3.48,
#       'mealAverage': 4.18}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 73870,
#       'hotelName': 'コンフォートホテル那覇県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=73870',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=73870&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=73870',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=73870',
#       'hotelKanaName': 'こんふぉーとほてるなはけんちょうまえ',
#       'hotelSpecial': 'モノレール県庁前駅徒歩３分◆国際通り徒歩3分◆無料朝食◆小学生まで添い寝無料◆全室禁煙Wi-Fi対応',
#       'hotelMinCharge': 3750,
#       'latitude': 94354.31,
#       'longitude': 459645.66,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地1-3-11',
#       'telephoneNo': '098-941-7311',
#       'faxNo': '098-941-7312',
#       'access': 'モノレール（ゆいレール）県庁前駅徒歩３分◆那覇空港モノレール１３分・車１０分◆沖縄県庁、国際通り徒歩３分',
#       'parkingInformation': '1泊820円（15：00〜翌12：00）敷地内駐車場5台',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/73870.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870_sig.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/73870.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870map.gif',
#       'reviewCount': 2807,
#       'reviewAverage': 4.24,
#       'userReview': '部屋が綺麗で良かった。\u30002023-10-12 07:07:20投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.16,
#       'locationAverage': 4.61,
#       'roomAverage': 4.07,
#       'equipmentAverage': 3.74,
#       'bathAverage': 3.35,
#       'mealAverage': 3.82}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 76923,
#       'hotelName': '那覇東急ＲＥＩホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=76923',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=76923&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=76923',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=76923',
#       'hotelKanaName': 'なはとうきゅうＲＥＩ',
#       'hotelSpecial': '那覇空港や国際通りからすぐの市内中心地にあり、ビジネス・レジャーに最適！',
#       'hotelMinCharge': 4370,
#       'latitude': 94340.7,
#       'longitude': 459644.78,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町116-37（「カフーナ旭橋」内、自治会館隣）',
#       'telephoneNo': '098-869-0109',
#       'faxNo': '098-869-0179',
#       'access': '空港からホテル約15分/ゆいレール「旭橋駅」から連絡通路直結/国際通り入口徒歩約10分/那覇バスターミナル徒歩約3分',
#       'parkingInformation': 'カフーナ旭橋駐車場“E棟”(ホテル向かい)\u3000約100台\u30001泊最大1,500円(15時〜翌日10時)',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/76923.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/76923.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/76923/76923map.gif',
#       'reviewCount': 1218,
#       'reviewAverage': 4.32,
#       'userReview': '駅直結なので空港ついてからホテルまでスムーズに移動できました。とにかく安かったのでそこまでクオリティを気にしていませんでしたが、部屋内は綺麗だし、アメニティも充実してました。またぜひ予約したいです。\u30002023-10-05 20:13:18投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.18,
#       'locationAverage': 4.52,
#       'roomAverage': 4.45,
#       'equipmentAverage': 4.06,
#       'bathAverage': 3.58,
#       'mealAverage': 4.05}}]}]}

# %% [markdown]
# ## 4.全体像：取得したデータをエクセルのように扱う

# %% [markdown]
# ### 4.1.実際にやる事

# %% [markdown]
# APIから得られたjsonで得られたデータを確認します。
# jsonだと人間にはわかりずらく、データ加工が難しいため、pandasを使ってエクセルのように変換します。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelName']　を変数を扱う事で、どのホテルのデータでも見れるようにしましょう。
# i = 0として１つ目のホテルの情報を見てみましょう。

i = 0
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['hotelName'])
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['hotelMinCharge'])
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['reviewAverage'])
# printで表示
# Out:
# ホテルリソルトリニティ那覇
# 4200
# 4.4

# %% [markdown]
# ### 4.2.データの確認と扱い方

# %% [markdown]
# 取得しただけではデータを活用できないので、取得したデータを扱っていきます。
#
# 全体像としては
# - 取得したjsonデータを確認
# - jsonでは確認しずらく、扱いずらいので、pandasというライブラリを使って扱いやすくする

# %% [markdown]
# #### 取得したデータの中身を詳しく確認してみましょう。

# %% [markdown]
# ※取得したデータの全体像

# %% [markdown]
# <img style="background-color:#fff;" src="img/img034.png">
# <img style="background-color:#fff;" src="img/img035.png">

# %% [markdown]
# 参照：https://jsoncrack.com/editor

# %% [markdown]
# 取得したデータの内容は result['hotels'][ここ行の場所]['hotel'][0]['hotelBasicInfo'] に格納されており、
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']とすることで、１つ目に格納されているホテルの詳細を取得する事ができます

# %%
# データの中身を紐解いていく
result['hotels'][0]['hotel'][0]['hotelBasicInfo']
# Out:
# {'hotelNo': 182884,
#  'hotelName': 'ホテルリソルトリニティ那覇',
#  'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182884',
#  'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN',
#  'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182884',
#  'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884',
#  'hotelKanaName': 'ほてるりぞるとりにてぃなは',
#  'hotelSpecial': '2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。',
#  'hotelMinCharge': 4200,
#  'latitude': 94341.93,
#  'longitude': 459641.13,
#  'postalCode': '900-0029',
#  'address1': '沖縄県',
#  'address2': '那覇市旭町7',
#  'telephoneNo': '098-863-9269',
#  'faxNo': '098-863-9279',
#  'access': 'ゆいレール「旭橋駅」出入口2より徒歩3分',
#  'parkingInformation': '機械式立体駐車場50台1泊1,500円 ※台風・災害時など利用不可※先着順予約不可',
#  'nearestStation': '那覇空港',
#  'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884.jpg',
#  'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182884.jpg',
#  'roomImageUrl': None,
#  'roomThumbnailUrl': None,
#  'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884map.gif',
#  'reviewCount': 243,
#  'reviewAverage': 4.4,
#  'userReview': 'あまり広いお部屋ではないですが、木を基調とした柔らかい雰囲気で清潔感があり、とても居心地がよかったです。大浴場は、タイルが光に当たるととても綺麗で、旅の疲れが癒やされました。とにかく内装がとて…\u30002023-10-12 11:47:19投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884" class="3click">つづきはこちら</a>'}

# %% [markdown]
# どんなホテルの詳細情報項目があるか確認してみましょう！
# result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で確認することができます。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']になんの項目が含まれているかをkeys()で確認できます。
result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()
# Out:
# dict_keys(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl', 'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial', 'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1', 'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation', 'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl', 'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage', 'userReview'])

# %% [markdown]
# hotelNameという項目があるので、ホテルの名前などを取得してみましょう

# %%
# ホテル名の取得
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelName']
# Out:
# 'ホテルリソルトリニティ那覇'

# %%
#URLの取得
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['planListUrl']
# Out:
# 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN'

# %%
# 最低料金
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelMinCharge']
# Out:
# 4200

# %%
# 平均レビュー
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['reviewAverage']
# Out:
# 4.4

# %% [markdown]
# #### データを扱いやすくするために可視化する

# %% [markdown]
# ##### pandasを使ったデータの可視化

# %% [markdown]
# APIで得られたデータをpandasを用いてエクセルのような見やすいデータに変換してみましょう！

# %% [markdown]
# ライブラリのpandasをインポートしましょう！
# as pdとつけて、短くpdとコーディングできるようにします。

# %%
#pandasのインポート
import pandas as pd

# %% [markdown]
# データをpandasのDataFrameに格納してみましょう！
# また、DataFrameとはどのような変換をしてくれるか確認してみましょう。

# %%
# １つめのホテルのデータをhotel_infoに代入します。
hotel_info = result['hotels'][0]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info, index=[0])
# Out:
#    hotelNo      hotelName                                hotelInformationUrl  \
# 0   182884  ホテルリソルトリニティ那覇  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl  hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  ほてるりぞるとりにてぃなは
#
#                                       hotelSpecial  hotelMinCharge  latitude  \
# 0  2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。            4200  94341.93
#
#    ...                         parkingInformation nearestStation  \
# 0  ...  機械式立体駐車場50台1泊1,500円 ※台風・災害時など利用不可※先着順予約不可           那覇空港
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                    hotelThumbnailUrl roomImageUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/90/18288...         None
#
#   roomThumbnailUrl                                   hotelMapImageUrl  \
# 0             None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#   reviewCount reviewAverage                                         userReview
# 0         243           4.4  あまり広いお部屋ではないですが、木を基調とした柔らかい雰囲気で清潔感があり、とても居心地がよ...
#
# [1 rows x 27 columns]

# %% [markdown]
# indexの数字を変数iにして、他のホテル情報も確認してみましょう！
# iの数字を変えると取得できるホテルを変更できる事も確認してみましょう

# %%
#index番号の指定。ここの数字を変えると格納されるデータが変わります。
i = 1
# その番号に対応するホテル情報を取得し、hotel_infoに代入
hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info, index=[i])

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
# Out:
#    hotelNo          hotelName  \
# 1   128440  ダイワロイネットホテル那覇国際通り
#
#                                  hotelInformationUrl  \
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl       hotelKanaName  \
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっと　なはこくさいどおり
#
#                                 hotelSpecial  hotelMinCharge  latitude  ...  \
# 1  国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪            3830   94369.8  ...
#
#                                  parkingInformation nearestStation  \
# 1  当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）           None
#
#                                        hotelImageUrl  \
# 1  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                    hotelThumbnailUrl  \
# 1  https://img.travel.rakuten.co.jp/HIMG/90/12844...
#
#                                         roomImageUrl  \
# 1  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                     roomThumbnailUrl  \
# 1  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                     hotelMapImageUrl reviewCount  \
# 1  https://img.travel.rakuten.co.jp/share/HOTEL/1...        1465
#
#   reviewAverage                                         userReview
# 1          4.37  まず立地が抜群に良いです。天気悪くてもゆいレール牧志駅から屋根付きの連絡通路があり安心です。...
#
# [1 rows x 27 columns]

# %% [markdown]
# 個別のデータを格納できたので、データ全体を格納してみましょう。
#
# そのためにAPIで取得したホテルのデータ数を確認してみましょう！
# len(確認したい配列)でデータ数を確認できます！

# %%
# len(ここに配列に含まれる要素)で配列に含まれる要素の数を取得できます。
len(result['hotels'])
# Out:
# 30

# %% [markdown]
# 30あるホテルのデータをfor文を使ってまとめてみましょう！

# %%
#空のpandasデータフレームを用意して、生成した1つ１つのデータフレームをこのdfに結合して１つにします。
df = pd.DataFrame()

# iにrange(0,len(result['hotels']))である0～29の数字が１つずつ代入されて実行されます。
# 今回は30のデータとわかっているのでfor i in range(0,30)でも問題ないですが、30とは限らないのでデータ園生数であるlen(result['hotels'])を使います。
for i in range(0, len(result['hotels'])):
    hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo']
    temp_df = pd.DataFrame(hotel_info, index=[i])
    df = pd.concat([df, temp_df])
#格納する配列をhotel_infoに代入する
#hotel_infoに代入されたホテルのデータをデータフレームに変換します。

#dfに結合して１つにまとめます。

# %% [markdown]
# まとめたデータをdisplay(df) で確認してみましょう！

# %%
# dfの表示
display(df)
# Out:
#     hotelNo                              hotelName  \
# 0    182884                          ホテルリソルトリニティ那覇
# 1    128440                      ダイワロイネットホテル那覇国際通り
# 2    134763                     ダイワロイネットホテル那覇おもろまち
# 3    148000                       ハイアットリージェンシー那覇沖縄
# 4     16443                             ロワジールホテル那覇
# 5    181785                           ヒューイットリゾート那覇
# 6    104526                       ダイワロイネットホテル沖縄県庁前
# 7    177761                              東急ステイ沖縄那覇
# 8    167519                               ノボテル沖縄那覇
# 9    176757                           沖縄ハーバービューホテル
# 10   178447           ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯
# 11    71990                             ホテル　ロコア　ナハ
# 12   163087                            ホテルアクアチッタナハ
# 13   178292                            ホテル　ストレータ那覇
# 14   149369                            ホテルグレイスリー那覇
# 15   136808                           リーガロイヤルグラン沖縄
# 16    18195                          サンプラザホテル＜沖縄県＞
# 17    38282                     ホテルパームロイヤルNAHA国際通り
# 18   171943                  沖縄かりゆしリゾートエグゼス那覇＜県庁前＞
# 19   130025                             西鉄リゾートイン那覇
# 20    67292                              アパホテル〈那覇〉
# 21    19934                         リッチモンドホテル那覇久茂地
# 22    40768        アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)
# 23    78094                           ロワジールスパタワー那覇
# 24    43753                            ソルヴィータホテル那覇
# 25   160939                        ＪＲ九州ホテル　ブラッサム那覇
# 26   184913  Ｓｏｕｔｈｗｅｓｔ　Ｇｒａｎｄ　Ｈｏｔｅｌ（２０２３年６月２０日新規開業）
# 27   181957                     ＯＭＯ５沖縄那覇　ｂｙ　星野リゾート
# 28    73870                         コンフォートホテル那覇県庁前
# 29    76923                             那覇東急ＲＥＩホテル
#
#                                   hotelInformationUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                           planListUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                         dpPlanListUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                             reviewUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                        hotelKanaName  \
# 0                      ほてるりぞるとりにてぃなは
# 1                 だいわろいねっと　なはこくさいどおり
# 2                 だいわろいねっとほてるなはおもろまち
# 3                 はいあっとりーじぇんしーなはおきなわ
# 4                         ろわじーるほてるなは
# 5                       ひゅーいっとりぞーとなは
# 6             だいわろいねっとほてるおきなわけんちょうまえ
# 7                   とうきゅうすてい　おきなわ　なは
# 8                       のぼてる　おきなわ　なは
# 9                     おきなわはーばーびゅーほてる
# 10  ほてる　さんすい　なは　りゅうきゅうおんせん　なみのうえおんせん
# 11                            ろこあ　なは
# 12                       ほてるあくあちったなは
# 13                           すとれーたなは
# 14                          ぐれいすりーなは
# 15                    りーがろいやるぐらんおきなわ
# 16                  さんぷらざほてる＜おきなわけん＞
# 17                ぱーむろいやる　なは　こくさいどおり
# 18            おきなわ　かりゆし　りぞーと　えぐぜす　なは
# 19                      にしてつりぞーといんなは
# 20                          あぱほてる　なは
# 21                     りっちもんど　なは　くもじ
# 22                   あるもんとほてるなはおもろまち
# 23                      ろわじーるすぱたわーなは
# 24                      そるう゛ぃーたほてるなは
# 25           じぇいあーるきゅうしゅうほてる　ぶらっさむなは
# 26                    さうすうえすとぐらんどほてる
# 27             おも５　おきなわなは　ばい　ほしのりぞーと
# 28                こんふぉーとほてるなはけんちょうまえ
# 29                        なはとうきゅうＲＥＩ
#
#                                          hotelSpecial  hotelMinCharge  \
# 0     2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。            4200
# 1           国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪            3830
# 2   海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎            3800
# 3     グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。            7926
# 4     空港から車で約7分。天然温泉大浴場、室内外プールと館内施設が充実♪■楽天認定プレミアムホテル■            5142
# 5            2021年7月15日OPEN！朝食ブッフェは宿泊の皆様に無料でご提供いたします！            5110
# 6    那覇空港より１５分。県庁等官庁街へ徒歩２分、人気の国際通りへは徒歩３分でビジネス・観光に好立地。            4500
# 7   食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチ...            5550
# 8   国際通りから車で約５分、那覇にいてもリゾート気分を！クラブラウンジやインフィニティプールがあ...            5850
# 9    楽天トラベルからのご予約限定☆楽天専用ラウンジOPEN☆お飲み物やアメニティをご用意しております            3375
# 10                癒しの波上温泉とシースループール完備で那覇空港に一番近いスパ＆リゾート            4386
# 11        目の前が国際通り！空港直通ゆいレール駅から徒歩2分！朝食バイキングは口コミでも高評価♪            4600
# 12      シースループール◆那覇の夜景を望めるナイトプールが人気◆地中海の朝市をコンセプトにした朝食            4464
# 13      「美栄橋」から、新しい沖縄らしさを育み、発信していく場所となっていくことを目指しています。            4250
# 14  ★国際通り徒歩0分！★バス・トイレ別で、観光・出張も快適に♪焼きたてあぐー豚が人気の朝食ビュッフェ            5000
# 15   【エントリーと予約でポイント増量参画中】「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド            7466
# 16    ゆいレール牧志駅から徒歩5分。那覇のメインストリート国際通り近く、大浴場・コインランドリー有。            2000
# 17          ＼国際通りから一歩入ると現れる楽園／ナノ水ロイヤルスパや朝食KUNCHIめしも人気            4100
# 18    那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）            8920
# 19                  ゆいレール県庁前駅から徒歩３分。歩いて国際通りへ、便利なアクセス♪            4200
# 20   沖縄最大の繁華街奇跡の1マイルと評される「国際通り」徒歩9分、疲れた体は大浴場（無料）で癒せます            3600
# 21  国際通りやケラマ諸島へのアクセス泊港へも徒歩でOK◎美栄橋駅より徒歩２分☆1階セブンイレブンが便利            3170
# 22                 ２０２０年４月１日から『アルモントホテル那覇おもろまち』へリブランド            3700
# 23      天然温泉を24時間楽しめる客室有！全室バルコニー付、24時間利用できるフィットネスジム完備            7968
# 24  宿泊者専用ラウンジあり、アイスやドリンクあり。小学生まで添い寝利用可！タオルやキッズアメニテ...            3450
# 25                     国際通りむつみ橋交差点徒歩1分。ゆいレール美栄橋駅徒歩５分。            7200
# 26                        【2023年6月開業！】楽天限定開業記念プラン販売中！           13750
# 27       国際通りから徒歩8分の好アクセス★寝るだけでは終わらせない、旅のテンションをあげるホテル            3200
# 28  モノレール県庁前駅徒歩３分◆国際通り徒歩3分◆無料朝食◆小学生まで添い寝無料◆全室禁煙Wi-...            3750
# 29               那覇空港や国際通りからすぐの市内中心地にあり、ビジネス・レジャーに最適！            4370
#
#     latitude  ...                                 parkingInformation  \
# 0   94341.93  ...          機械式立体駐車場50台1泊1,500円 ※台風・災害時など利用不可※先着順予約不可
# 1   94369.80  ...   当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）
# 2   94389.24  ...  1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用...
# 3   94357.69  ...  立体駐車場・地下駐車場完備　１１３台　1泊1台あたり1,500円（税込）　（予約不要／出し入...
# 4   94355.14  ...                                         1泊1台1,800円
# 5   94371.18  ...                                有り　84台　1,650円（税込）/泊
# 6   94353.12  ...   有り　１台　１０５０円（税込み／泊）　先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。
# 7   94334.89  ...  屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に...
# 8   94374.60  ...                             有り（1泊1台1,000円）　※事前予約不可
# 9   94336.98  ...                           有り　１９０台　１８００円（税込み／泊）　先着順
# 10  94372.73  ...            有り　42台　1,500円（税込み／泊）　先着順　※高さ制限有（175センチ）
# 11  94354.63  ...                    提携駐車場１泊1台１5００円。営業時間外の入出庫不可。先着順。
# 12  94385.53  ...  有 60台 1,200円（税込／泊）高さ制限1.55ｍ ※先着順　その他のお車は近隣駐車場をご案内
# 13  94373.92  ...                             立体駐車場48台：\1,500/1泊　到着順
# 14  94356.90  ...                        近隣（徒歩5分ほど）のコインパーキングをご案内します。
# 15  94344.00  ...        有り　料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します
# 16  94378.86  ...       有り　先着順40台予約不可￥1000/泊※バス・大型車などの駐車は電話でお問合せ下さい。
# 17  94365.08  ...   【有り：60台】1泊1100円（税込）満車の場合は近隣のコインパーキングをご利用下さい。※先着順
# 18  94353.21  ...    有り　４２台　１５００円（税込／泊）　満車の場合は周辺のコインパーキングをご利用くださいませ。
# 19  94361.44  ...                                有り４０台（先着順）１，２００円/泊。
# 20  94371.20  ...         立体駐車場先着順46台1泊1,500円 【車高1.8m制限有】※新規入庫は23時迄
# 21  94378.89  ...  立体駐車場(車高2ｍ)1泊 1台1,000円 ※先着順でご利用いただけます(予約制ではござい...
# 22  94395.88  ...                            有り　30台　1,100円（税込／泊）　先着順
# 23  94353.28  ...                                         1泊1,800円/台
# 24  94376.95  ...           有り　40台（1500円／泊  ）先着順・予約不可　平面駐車場で出し入れラクラク
# 25  94367.20  ...                          有り　１１２台　１５００円（税込み／泊）　予約不可
# 26  94361.90  ...  あり　10台　1500円（税込／泊）　先着順　※満車の場合は近隣のコインパーキングをご利用ください
# 27  94368.45  ...  立体駐車場44台（1泊￥1500・車高1.9Mまで）先着順10:00PM〜6:00AMは入出庫不可
# 28  94354.31  ...                       1泊820円（15：00〜翌12：00）敷地内駐車場5台
# 29  94340.70  ...  カフーナ旭橋駐車場“E棟”(ホテル向かい)　約100台　1泊最大1,500円(15時〜翌日10時)
#
#    nearestStation                                      hotelImageUrl  \
# 0            那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 1            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 2            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 3            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 4            那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 5            那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 6            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 7            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 8            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 9            那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 10           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 11           None  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 12           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 13           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 14           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15             旭橋  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 16           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 17           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/3...
# 18           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 19           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 20           None  https://img.travel.rakuten.co.jp/share/HOTEL/6...
# 21           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 22           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 23           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 24           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 25           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 26           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 27           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 28           None  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 29             旭橋  https://img.travel.rakuten.co.jp/share/HOTEL/7...
#
#                                     hotelThumbnailUrl  \
# 0   https://img.travel.rakuten.co.jp/HIMG/90/18288...
# 1   https://img.travel.rakuten.co.jp/HIMG/90/12844...
# 2   https://img.travel.rakuten.co.jp/HIMG/90/13476...
# 3   https://img.travel.rakuten.co.jp/HIMG/90/14800...
# 4   https://img.travel.rakuten.co.jp/HIMG/90/16443...
# 5   https://img.travel.rakuten.co.jp/HIMG/90/18178...
# 6   https://img.travel.rakuten.co.jp/HIMG/90/10452...
# 7   https://img.travel.rakuten.co.jp/HIMG/90/17776...
# 8   https://img.travel.rakuten.co.jp/HIMG/90/16751...
# 9   https://img.travel.rakuten.co.jp/HIMG/90/17675...
# 10  https://img.travel.rakuten.co.jp/HIMG/90/17844...
# 11  https://img.travel.rakuten.co.jp/HIMG/90/71990...
# 12  https://img.travel.rakuten.co.jp/HIMG/90/16308...
# 13  https://img.travel.rakuten.co.jp/HIMG/90/17829...
# 14  https://img.travel.rakuten.co.jp/HIMG/90/14936...
# 15  https://img.travel.rakuten.co.jp/HIMG/90/13680...
# 16  https://img.travel.rakuten.co.jp/HIMG/90/18195...
# 17  https://img.travel.rakuten.co.jp/HIMG/90/38282...
# 18  https://img.travel.rakuten.co.jp/HIMG/90/17194...
# 19  https://img.travel.rakuten.co.jp/HIMG/90/13002...
# 20  https://img.travel.rakuten.co.jp/HIMG/90/67292...
# 21  https://img.travel.rakuten.co.jp/HIMG/90/19934...
# 22  https://img.travel.rakuten.co.jp/HIMG/90/40768...
# 23  https://img.travel.rakuten.co.jp/HIMG/90/78094...
# 24  https://img.travel.rakuten.co.jp/HIMG/90/43753...
# 25  https://img.travel.rakuten.co.jp/HIMG/90/16093...
# 26  https://img.travel.rakuten.co.jp/HIMG/90/18491...
# 27  https://img.travel.rakuten.co.jp/HIMG/90/18195...
# 28  https://img.travel.rakuten.co.jp/HIMG/90/73870...
# 29  https://img.travel.rakuten.co.jp/HIMG/90/76923...
#
#                                          roomImageUrl  \
# 0                                                None
# 1   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 4   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 5                                                None
# 6   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 7                                                None
# 8   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 9   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 10                                               None
# 11  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 13                                               None
# 14  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 16  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 17  https://img.travel.rakuten.co.jp/share/HOTEL/3...
# 18                                               None
# 19  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 20  https://img.travel.rakuten.co.jp/share/HOTEL/6...
# 21                                               None
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 23  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 24  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 25  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 26                                               None
# 27                                               None
# 28  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 29  https://img.travel.rakuten.co.jp/share/HOTEL/7...
#
#                                      roomThumbnailUrl  \
# 0                                                None
# 1   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 2   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 3   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 4   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 5                                                None
# 6   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 7                                                None
# 8   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 9   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 10                                               None
# 11  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 12  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 13                                               None
# 14  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 15  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 16  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 17  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 18                                               None
# 19  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 20  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 21                                               None
# 22  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 23  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 24  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 25  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 26                                               None
# 27                                               None
# 28  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 29  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                      hotelMapImageUrl reviewCount  \
# 0   https://img.travel.rakuten.co.jp/share/HOTEL/1...         243
# 1   https://img.travel.rakuten.co.jp/share/HOTEL/1...        1465
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...         997
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/1...         633
# 4   https://img.travel.rakuten.co.jp/share/HOTEL/1...        1351
# 5   https://img.travel.rakuten.co.jp/share/HOTEL/1...         270
# 6   https://img.travel.rakuten.co.jp/share/HOTEL/1...        1152
# 7   https://img.travel.rakuten.co.jp/share/HOTEL/1...         570
# 8   https://img.travel.rakuten.co.jp/share/HOTEL/1...         383
# 9   https://img.travel.rakuten.co.jp/share/HOTEL/1...         483
# 10  https://img.travel.rakuten.co.jp/share/HOTEL/1...         259
# 11  https://img.travel.rakuten.co.jp/share/HOTEL/7...        1742
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...         354
# 13  https://img.travel.rakuten.co.jp/share/HOTEL/1...         205
# 14  https://img.travel.rakuten.co.jp/share/HOTEL/1...         592
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/1...         615
# 16  https://img.travel.rakuten.co.jp/share/HOTEL/1...        2751
# 17  https://img.travel.rakuten.co.jp/share/HOTEL/3...        2273
# 18  https://img.travel.rakuten.co.jp/share/HOTEL/1...         112
# 19  https://img.travel.rakuten.co.jp/share/HOTEL/1...         809
# 20  https://img.travel.rakuten.co.jp/share/HOTEL/6...        2538
# 21  https://img.travel.rakuten.co.jp/share/HOTEL/1...        3681
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/4...        1512
# 23  https://img.travel.rakuten.co.jp/share/HOTEL/7...         480
# 24  https://img.travel.rakuten.co.jp/share/HOTEL/4...        1648
# 25  https://img.travel.rakuten.co.jp/share/HOTEL/1...         419
# 26  https://img.travel.rakuten.co.jp/share/HOTEL/1...           6
# 27  https://img.travel.rakuten.co.jp/share/HOTEL/1...          90
# 28  https://img.travel.rakuten.co.jp/share/HOTEL/7...        2807
# 29  https://img.travel.rakuten.co.jp/share/HOTEL/7...        1218
#
#    reviewAverage                                         userReview
# 0           4.40  あまり広いお部屋ではないですが、木を基調とした柔らかい雰囲気で清潔感があり、とても居心地がよ...
# 1           4.37  まず立地が抜群に良いです。天気悪くてもゆいレール牧志駅から屋根付きの連絡通路があり安心です。...
# 2           4.49  初めて利用しました非常に清潔、快適で素晴らしかったですまた利用したいホテルです　2023-1...
# 3           4.64  クラブアクセス付きにして大正解。お部屋も綺麗で快適でした。対応していただいたスタッフの皆様に...
# 4           3.93  沖縄のリーズナブルなホテルは総じてですが、大浴場はそこまでよくありません。が、十分疲れが取れ...
# 5           4.29  高級宿の表記もあり、口コミを見て予約しましたが見た目綺麗なビジネスホテルという感じでした。枕...
# 6           4.19  近くにコンビニもあり、助かります。モノレールも近いので、空港へのアクセスもいいです。デスクが...
# 7           4.48     立地がいい。下にドンキーがあるのもまたいいです。　2023-09-30 12:34:22投稿
# 8           4.40  綺麗なホテルでサービスも◎テラス付きの部屋にしました。素敵でした。テラスの椅子が少し汚れてた...
# 9           4.27  地元民です。クラブラウンジ付プランを利用しました。ゆっくりとホテルステイでき満足しています。...
# 10          4.14         朝食が沢山あり、どれも美味しかったです。　2023-10-06 22:45:55投稿
# 11          4.36  朝食がとにかくおいしいです。沖縄のいろいろな特産物があり、品数も豊富です。デザートのフルーツ...
# 12          4.32  全体的に綺麗です。フロント対応も良くてまた使いたいと思います。　2023-10-09 10:...
# 13          4.45  駅近なので移動に困りません。駐車場は立体なので大きな荷物はエントランスで荷下ろしがベスト。タ...
# 14          4.50  食事は外で頂く予定だったので、お部屋だけで宿泊しましたが立地も含めて大満足です(^^)また、...
# 15          4.67  今回初めて利用しましたが、ラグジュアリー感、清潔感、部屋も綺麗で最高でした!!スタッフさんの...
# 16          4.14  1人なのにツインの洋室と和室のある広い部屋でした。大浴場は快適でサッパリしました。部屋にドラ...
# 17          4.31  ビジネス利用ではありますが、定期的にこちらにお世話になっています。周辺にはハイアットやJR九...
# 18          4.61  前回同様プール付きの部屋を利用しました。観光目的ではなく部屋でのんびりするためにお世話になり...
# 19          4.32            エアコンの温度調整に苦労しました。　2023-10-10 08:31:48投稿
# 20          3.97                         よかった　2023-10-08 13:05:45投稿
# 21          4.18  大満足です。朝食美味しかったです。また利用したいです。　2023-10-03 18:38:52投稿
# 22          4.54  朝食が美味しいホテルだと口コミがあったので宿泊しました。とても美味しかったです！エレベーター...
# 23          3.96  部屋に入る前から嫌な思いばかりでした。まずチェックイン前の時間に到着して行列、1時間近く並び...
# 24          4.50                                               None
# 25          4.38  雨の日は無料の傘を貸し出しされているので助かりました。部屋のホコリが落ちて掃除をしました。ど...
# 26          4.33                                               None
# 27          4.26  お部屋の雰囲気もよく、国際通りからもアクセスしやすく大変良かったです。近くにコンビニもあり、...
# 28          4.24                  部屋が綺麗で良かった。　2023-10-12 07:07:20投稿
# 29          4.32  駅直結なので空港ついてからホテルまでスムーズに移動できました。とにかく安かったのでそこまでク...
#
# [30 rows x 27 columns]

# %% [markdown]
# df.columnsで項目の確認ができます！
# これはresult['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で取得した値と一致します

# %%
#カラムの表示
df.columns
# Out:
# Index(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl',
#        'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial',
#        'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1',
#        'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation',
#        'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl',
#        'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage',
#        'userReview'],
#       dtype='object')

# %% [markdown]
# ##### pandasを使ったデータ整理

# %% [markdown]
# まとめたデータから名前と値段と評価だけを取り出してみましょう！
# １つのカラムを取得する時は欲しいカラム名である"カラム名"を代入したdf["カラム名"]で取得できましたが、
# 複数選択する場合は、の代わりに配列である["カラム名1","カラム名2","カラム名3"]を代入してdf[["カラム名1","カラム名2","カラム名3"]]とする必要があります。

# %%
#[ 'hotelName', 'hotelMinCharge', 'reviewAverage']を表示
df[[ 'hotelName', 'hotelMinCharge', 'reviewAverage']]
# Out:
#                                 hotelName  hotelMinCharge  reviewAverage
# 0                           ホテルリソルトリニティ那覇            4200           4.40
# 1                       ダイワロイネットホテル那覇国際通り            3830           4.37
# 2                      ダイワロイネットホテル那覇おもろまち            3800           4.49
# 3                        ハイアットリージェンシー那覇沖縄            7926           4.64
# 4                              ロワジールホテル那覇            5142           3.93
# 5                            ヒューイットリゾート那覇            5110           4.29
# 6                        ダイワロイネットホテル沖縄県庁前            4500           4.19
# 7                               東急ステイ沖縄那覇            5550           4.48
# 8                                ノボテル沖縄那覇            5850           4.40
# 9                            沖縄ハーバービューホテル            3375           4.27
# 10           ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯            4386           4.14
# 11                             ホテル　ロコア　ナハ            4600           4.36
# 12                            ホテルアクアチッタナハ            4464           4.32
# 13                            ホテル　ストレータ那覇            4250           4.45
# 14                            ホテルグレイスリー那覇            5000           4.50
# 15                           リーガロイヤルグラン沖縄            7466           4.67
# 16                          サンプラザホテル＜沖縄県＞            2000           4.14
# 17                     ホテルパームロイヤルNAHA国際通り            4100           4.31
# 18                  沖縄かりゆしリゾートエグゼス那覇＜県庁前＞            8920           4.61
# 19                             西鉄リゾートイン那覇            4200           4.32
# 20                              アパホテル〈那覇〉            3600           3.97
# 21                         リッチモンドホテル那覇久茂地            3170           4.18
# 22        アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)            3700           4.54
# 23                           ロワジールスパタワー那覇            7968           3.96
# 24                            ソルヴィータホテル那覇            3450           4.50
# 25                        ＪＲ九州ホテル　ブラッサム那覇            7200           4.38
# 26  Ｓｏｕｔｈｗｅｓｔ　Ｇｒａｎｄ　Ｈｏｔｅｌ（２０２３年６月２０日新規開業）           13750           4.33
# 27                     ＯＭＯ５沖縄那覇　ｂｙ　星野リゾート            3200           4.26
# 28                         コンフォートホテル那覇県庁前            3750           4.24
# 29                             那覇東急ＲＥＩホテル            4370           4.32

# %% [markdown]
# 欲しいデータに絞って出力してみましょう！
# pandasの機能であるto_csvを使うとcsvファイルとして保存ができます

# %%
# dfの'hotelName', 'hotelInformationUrl', 'hotelMinCharge', 'telephoneNo', 'reviewAverage'を指定して、
# ここにデータフレーム.to_csv(ここにファイル名,データフレームで認識されているindex数字も出力するかどうか)で保存できます。
# このデータではindexの数字は必要ないので、index = Falseにします。
df[['hotelName', 'hotelInformationUrl', 'hotelMinCharge', 'telephoneNo', 'reviewAverage']].to_csv('hotel2.csv', index=False)

# %% [markdown]
# 今度は保存したcsvをdf2として読み込んでみましょう！

# %%
# pd.read_csv(ここにファイル名)でロードして、df2に代入します。
df2 = pd.read_csv('hotel2.csv')
df2
# Out:
#                                 hotelName  \
# 0                           ホテルリソルトリニティ那覇
# 1                       ダイワロイネットホテル那覇国際通り
# 2                      ダイワロイネットホテル那覇おもろまち
# 3                        ハイアットリージェンシー那覇沖縄
# 4                              ロワジールホテル那覇
# 5                            ヒューイットリゾート那覇
# 6                        ダイワロイネットホテル沖縄県庁前
# 7                               東急ステイ沖縄那覇
# 8                                ノボテル沖縄那覇
# 9                            沖縄ハーバービューホテル
# 10           ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯
# 11                             ホテル　ロコア　ナハ
# 12                            ホテルアクアチッタナハ
# 13                            ホテル　ストレータ那覇
# 14                            ホテルグレイスリー那覇
# 15                           リーガロイヤルグラン沖縄
# 16                          サンプラザホテル＜沖縄県＞
# 17                     ホテルパームロイヤルNAHA国際通り
# 18                  沖縄かりゆしリゾートエグゼス那覇＜県庁前＞
# 19                             西鉄リゾートイン那覇
# 20                              アパホテル〈那覇〉
# 21                         リッチモンドホテル那覇久茂地
# 22        アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)
# 23                           ロワジールスパタワー那覇
# 24                            ソルヴィータホテル那覇
# 25                        ＪＲ九州ホテル　ブラッサム那覇
# 26  Ｓｏｕｔｈｗｅｓｔ　Ｇｒａｎｄ　Ｈｏｔｅｌ（２０２３年６月２０日新規開業）
# 27                     ＯＭＯ５沖縄那覇　ｂｙ　星野リゾート
# 28                         コンフォートホテル那覇県庁前
# 29                             那覇東急ＲＥＩホテル
#
#                                   hotelInformationUrl  hotelMinCharge  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...            4200
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...            3830
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...            3800
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...            7926
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...            5142
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...            5110
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...            4500
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...            5550
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...            5850
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...            3375
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...            4386
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...            4600
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...            4464
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...            4250
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...            5000
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...            7466
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...            2000
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...            4100
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...            8920
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...            4200
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...            3600
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...            3170
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...            3700
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...            7968
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...            3450
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...            7200
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...           13750
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...            3200
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...            3750
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...            4370
#
#      telephoneNo  reviewAverage
# 0   098-863-9269           4.40
# 1   098-868-9055           4.37
# 2   098-862-4555           4.49
# 3   098-866-8888           4.64
# 4   098-868-2222           3.93
# 5   098-943-8325           4.29
# 6   098-860-1855           4.19
# 7   098-833-1090           4.48
# 8   098-887-1111           4.40
# 9   098-853-2111           4.27
# 10  0120-996-941           4.14
# 11  098-868-6578           4.36
# 12  0120-996-941           4.32
# 13  098-860-7400           4.45
# 14  098-867-6111           4.50
# 15  098-867-3331           4.67
# 16  098-866-0920           4.14
# 17  098-865-5551           4.31
# 18  098-860-3300           4.61
# 19  098-869-5454           4.32
# 20  098-868-9111           3.97
# 21  098-869-0077           4.18
# 22  098-860-6611           4.54
# 23  098-868-2222           3.96
# 24  098-863-1234           4.50
# 25  098-861-8700           4.38
# 26  098-860-0421           4.33
# 27   05031348095           4.26
# 28  098-941-7311           4.24
# 29  098-869-0109           4.32

# %% [markdown]
# まとめたデータから評価が4.5以上のホテルを検索してみましょう！

# %%
# df[ ここにそれぞれの行に対して出力するかどうかの条件文　]でデータを抽出できます。
# 今回は評価が4.5以上なので、df['reviewAverage'] > 4.5を条件とします。
df[df['reviewAverage'] > 4.5]
# Out:
#     hotelNo                        hotelName  \
# 3    148000                 ハイアットリージェンシー那覇沖縄
# 15   136808                     リーガロイヤルグラン沖縄
# 18   171943            沖縄かりゆしリゾートエグゼス那覇＜県庁前＞
# 22    40768  アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)
#
#                                   hotelInformationUrl  \
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                           planListUrl  \
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                         dpPlanListUrl  \
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                             reviewUrl           hotelKanaName  \
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...      はいあっとりーじぇんしーなはおきなわ
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...          りーがろいやるぐらんおきなわ
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...  おきなわ　かりゆし　りぞーと　えぐぜす　なは
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...         あるもんとほてるなはおもろまち
#
#                                         hotelSpecial  hotelMinCharge  \
# 3    グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。            7926
# 15  【エントリーと予約でポイント増量参画中】「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド            7466
# 18   那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）            8920
# 22                ２０２０年４月１日から『アルモントホテル那覇おもろまち』へリブランド            3700
#
#     latitude  ...                                 parkingInformation  \
# 3   94357.69  ...  立体駐車場・地下駐車場完備　１１３台　1泊1台あたり1,500円（税込）　（予約不要／出し入...
# 15  94344.00  ...        有り　料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します
# 18  94353.21  ...    有り　４２台　１５００円（税込／泊）　満車の場合は周辺のコインパーキングをご利用くださいませ。
# 22  94395.88  ...                            有り　30台　1,100円（税込／泊）　先着順
#
#    nearestStation                                      hotelImageUrl  \
# 3            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15             旭橋  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 18           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 22           那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                     hotelThumbnailUrl  \
# 3   https://img.travel.rakuten.co.jp/HIMG/90/14800...
# 15  https://img.travel.rakuten.co.jp/HIMG/90/13680...
# 18  https://img.travel.rakuten.co.jp/HIMG/90/17194...
# 22  https://img.travel.rakuten.co.jp/HIMG/90/40768...
#
#                                          roomImageUrl  \
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 18                                               None
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                      roomThumbnailUrl  \
# 3   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 15  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 18                                               None
# 22  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                      hotelMapImageUrl reviewCount  \
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/1...         633
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/1...         615
# 18  https://img.travel.rakuten.co.jp/share/HOTEL/1...         112
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/4...        1512
#
#    reviewAverage                                         userReview
# 3           4.64  クラブアクセス付きにして大正解。お部屋も綺麗で快適でした。対応していただいたスタッフの皆様に...
# 15          4.67  今回初めて利用しましたが、ラグジュアリー感、清潔感、部屋も綺麗で最高でした!!スタッフさんの...
# 18          4.61  前回同様プール付きの部屋を利用しました。観光目的ではなく部屋でのんびりするためにお世話になり...
# 22          4.54  朝食が美味しいホテルだと口コミがあったので宿泊しました。とても美味しかったです！エレベーター...
#
# [4 rows x 27 columns]

# %% [markdown]
# ### 課題

# %% [markdown]
# 検索して絞ったデータをdf2に格納して、ホテル名と評価とレビューだけ出力してみましょう！

# %%
# レビュー4.5以上を絞り込む
# ホテル名と評価とレビューだけ出力
df2 = df[df['reviewAverage'] > 4.5]
df2 = df2[['hotelName','reviewAverage','userReview']]
df2
# Out:
#                           hotelName  reviewAverage  \
# 3                  ハイアットリージェンシー那覇沖縄           4.64
# 15                     リーガロイヤルグラン沖縄           4.67
# 18            沖縄かりゆしリゾートエグゼス那覇＜県庁前＞           4.61
# 22  アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)           4.54
#
#                                            userReview
# 3   クラブアクセス付きにして大正解。お部屋も綺麗で快適でした。対応していただいたスタッフの皆様に...
# 15  今回初めて利用しましたが、ラグジュアリー感、清潔感、部屋も綺麗で最高でした!!スタッフさんの...
# 18  前回同様プール付きの部屋を利用しました。観光目的ではなく部屋でのんびりするためにお世話になり...
# 22  朝食が美味しいホテルだと口コミがあったので宿泊しました。とても美味しかったです！エレベーター...

# %% [markdown]
# - 同じ要領で楽天トラベル以外の楽天市場のデータを取得してください。
# - たどったフローを箇条書きまたは図式化してTAに提出してチェックうけてください
# - 発展
#     - 他のサービスのAPIで自分で構造化データまで取得してください。
#     - それを人に説明してください
